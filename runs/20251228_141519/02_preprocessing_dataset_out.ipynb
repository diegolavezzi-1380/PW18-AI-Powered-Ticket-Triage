# %% [markdown]
# # Preprocessing NLP per ticket di supporto
#
# In questo notebook vengono preparati i dati testuali dei ticket per l'addestramento dei modelli di classificazione:
# - costruzione del campo testuale (oggetto + descrizione)
# - pulizia testuale semplice e riproducibile
# - analisi di base delle lunghezze
# - suddivisione train/test senza leakage

# %%
import pandas as pd
import re

from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"

from sklearn.model_selection import train_test_split

pd.set_option("display.max_colwidth", 200)

df = pd.read_csv(DATA_DIR / "raw" / "tickets_realistic.csv")

print("Shape iniziale:", df.shape)
df.head()
# Out:
# Shape iniziale: (480, 7)
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                          title  \
# 0                                        Errore stampa: impossibile stampare fattura 2303/20 (cliente aspetta)
# 1                     Funzione rotta: tasto upload PDF non cliccabile con sconto per performance disponibilità
# 2                                                   Account bloccato: utente admin_01 fermo (troppi tentativi)
# 3  Errore calcolo IVA: importo errato su fattura estera (non validabile) con bug con login fallito memory leak
# 4   Blocco sistema durante elaborazione fattura 8373/22 per Righi, Federici e Morosini e figli con performance
#
#                                                                                                                                                                                                       body  \
# 0  Procedura di backup storico: export fatture anno 2017 per rachivio sicurezza. Generazione ifle statico in formato Excel da conseravre server-side. Operazione a bassa priorità da accodare ai job no...
# 1  Proposta di manutenzione ordinaria: pulizia account inattivi da lungo periodo. Lista di 9 utenti che non acceodno da mesi. Attività di igiene del database da schedulare come tsak di routine. Nessu...
# 2  err. validazione codice fiscale per nuovo cliente Barmbilla-Pizzo s.r.l.. Il system lo segna come errato anche se è formalmente valido. Impedisce il salvataggio della scheda cliente. Necessario by...
# 3  Procedura di backup storico: export fatture anno 2015 per archivio sicurezza. Generazione file statico in formato Excel da conservare server-side. Operazione a bassa priorità da accodare ai job no...
# 4  Attività di background: archiviazione documenti storici cliente Righi, Federici e Morosini e filgi per anno 2022. Si tratta di spostare vecchi file (fatture, contratti) nell'archivio morto per lib...
#
#           category priority  title_length  body_length
# 0  Amministrazione    media            69          268
# 1  Amministrazione    bassa            88          293
# 2  Amministrazione     alta            58          257
# 3  Amministrazione    media           107          317
# 4  Amministrazione    bassa           106          345

# %% [markdown]
# ## 2. Costruzione del campo testuale unico
#
# Vengono uniti oggetto e descrizione del ticket in un singolo campo `text`, che sarà utilizzato come input testuale per tutti i modelli.

# %%
TITLE_COL = "title"      
BODY_COL  = "body"       

# Controllo che le colonne esistano
print("Colonne presenti:", df.columns.tolist())
if TITLE_COL not in df.columns or BODY_COL not in df.columns:
    raise ValueError(f"Le colonne {TITLE_COL} e/o {BODY_COL} non esistono nel dataset. Adattale prima di proseguire.")

# Costruzione del campo testuale
df["text"] = (
    df[TITLE_COL].fillna("").astype(str) + " " + df[BODY_COL].fillna("").astype(str)
).str.strip()

# Rimuovo righe con testo completamente vuoto
before = df.shape[0]
df = df[df["text"].str.len() > 0].copy()
after = df.shape[0]

print(f"Righe totali dopo rimozione testi vuoti: {after} (rimosse {before - after})")
df[["id", TITLE_COL, BODY_COL, "text"]].head()
# Out:
# Colonne presenti: ['id', 'title', 'body', 'category', 'priority', 'title_length', 'body_length']
# Righe totali dopo rimozione testi vuoti: 480 (rimosse 0)
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                          title  \
# 0                                        Errore stampa: impossibile stampare fattura 2303/20 (cliente aspetta)
# 1                     Funzione rotta: tasto upload PDF non cliccabile con sconto per performance disponibilità
# 2                                                   Account bloccato: utente admin_01 fermo (troppi tentativi)
# 3  Errore calcolo IVA: importo errato su fattura estera (non validabile) con bug con login fallito memory leak
# 4   Blocco sistema durante elaborazione fattura 8373/22 per Righi, Federici e Morosini e figli con performance
#
#                                                                                                                                                                                                       body  \
# 0  Procedura di backup storico: export fatture anno 2017 per rachivio sicurezza. Generazione ifle statico in formato Excel da conseravre server-side. Operazione a bassa priorità da accodare ai job no...
# 1  Proposta di manutenzione ordinaria: pulizia account inattivi da lungo periodo. Lista di 9 utenti che non acceodno da mesi. Attività di igiene del database da schedulare come tsak di routine. Nessu...
# 2  err. validazione codice fiscale per nuovo cliente Barmbilla-Pizzo s.r.l.. Il system lo segna come errato anche se è formalmente valido. Impedisce il salvataggio della scheda cliente. Necessario by...
# 3  Procedura di backup storico: export fatture anno 2015 per archivio sicurezza. Generazione file statico in formato Excel da conservare server-side. Operazione a bassa priorità da accodare ai job no...
# 4  Attività di background: archiviazione documenti storici cliente Righi, Federici e Morosini e filgi per anno 2022. Si tratta di spostare vecchi file (fatture, contratti) nell'archivio morto per lib...
#
#                                                                                                                                                                                                       text
# 0  Errore stampa: impossibile stampare fattura 2303/20 (cliente aspetta) Procedura di backup storico: export fatture anno 2017 per rachivio sicurezza. Generazione ifle statico in formato Excel da con...
# 1  Funzione rotta: tasto upload PDF non cliccabile con sconto per performance disponibilità Proposta di manutenzione ordinaria: pulizia account inattivi da lungo periodo. Lista di 9 utenti che non ac...
# 2  Account bloccato: utente admin_01 fermo (troppi tentativi) err. validazione codice fiscale per nuovo cliente Barmbilla-Pizzo s.r.l.. Il system lo segna come errato anche se è formalmente valido. I...
# 3  Errore calcolo IVA: importo errato su fattura estera (non validabile) con bug con login fallito memory leak Procedura di backup storico: export fatture anno 2015 per archivio sicurezza. Generazion...
# 4  Blocco sistema durante elaborazione fattura 8373/22 per Righi, Federici e Morosini e figli con performance Attività di background: archiviazione documenti storici cliente Righi, Federici e Morosin...

# %% [markdown]
# ## 3. Pulizia testuale semplice
#
# Viene definita una funzione `clean_text` che applica:
#
# - conversione in minuscolo
# - rimozione dei simboli non utili
# - normalizzazione degli spazi

# %%
def clean_text(text: str) -> str:
    if not isinstance(text, str):
        text = "" if text is None else str(text)
        
    # minuscole (e togli lowercase=False dal TFIDF)
    text = text.lower()
    
    # rimuovi solo simboli non utili
    text = re.sub(r"[^\w\sàèéìòù]", " ", text)
    
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Test veloce della funzione su un esempio
example = "URGENTE: Fattura 12345 non pagata!!!"
print("Originale:", example)
print("Pulito   :", clean_text(example))
# Out:
# Originale: URGENTE: Fattura 12345 non pagata!!!
# Pulito   : urgente fattura 12345 non pagata

# %% [markdown]
# ## 4. Applicazione della pulizia e controlli di base
#
# Applicazione di `clean_text` al campo `text` per ottenere `text_clean` e verifica dei primi 5 record prima/dopo

# %%
df["text_clean"] = df["text"].apply(clean_text)

print("Esempi di testo prima/dopo:\n")
for i in range(5):
    print(f"--- Ticket {i} ---")
    print("TEXT      :", df.iloc[i]["text"])
    print("TEXT_CLEAN:", df.iloc[i]["text_clean"])
    print()
# Out:
# Esempi di testo prima/dopo:
#
# --- Ticket 0 ---
# TEXT      : Errore stampa: impossibile stampare fattura 2303/20 (cliente aspetta) Procedura di backup storico: export fatture anno 2017 per rachivio sicurezza. Generazione ifle statico in formato Excel da conseravre server-side. Operazione a bassa priorità da accodare ai job notturni o weekend. Serve sool per compliance e non per attività correnti.
# TEXT_CLEAN: errore stampa impossibile stampare fattura 2303 20 cliente aspetta procedura di backup storico export fatture anno 2017 per rachivio sicurezza generazione ifle statico in formato excel da conseravre server side operazione a bassa priorità da accodare ai job notturni o weekend serve sool per compliance e non per attività correnti
#
# --- Ticket 1 ---
# TEXT      : Funzione rotta: tasto upload PDF non cliccabile con sconto per performance disponibilità Proposta di manutenzione ordinaria: pulizia account inattivi da lungo periodo. Lista di 9 utenti che non acceodno da mesi. Attività di igiene del database da schedulare come tsak di routine. Nessun impatto sugli utenti attivi o sul servizio di produzione. preventivo con condizioni commerciali
# TEXT_CLEAN: funzione rotta tasto upload pdf non cliccabile con sconto per performance disponibilità proposta di manutenzione ordinaria pulizia account inattivi da lungo periodo lista di 9 utenti che non acceodno da mesi attività di igiene del database da schedulare come tsak di routine nessun impatto sugli utenti attivi o sul servizio di produzione preventivo con condizioni commerciali
#
# --- Ticket 2 ---
# TEXT      : Account bloccato: utente admin_01 fermo (troppi tentativi) err. validazione codice fiscale per nuovo cliente Barmbilla-Pizzo s.r.l.. Il system lo segna come errato anche se è formalmente valido. Impedisce il salvataggio della scheda cliente. Necessario bypassare il controllo o correggere l'algoritmo di validazione.
# TEXT_CLEAN: account bloccato utente admin_01 fermo troppi tentativi err validazione codice fiscale per nuovo cliente barmbilla pizzo s r l il system lo segna come errato anche se è formalmente valido impedisce il salvataggio della scheda cliente necessario bypassare il controllo o correggere l algoritmo di validazione
#
# --- Ticket 3 ---
# TEXT      : Errore calcolo IVA: importo errato su fattura estera (non validabile) con bug con login fallito memory leak Procedura di backup storico: export fatture anno 2015 per archivio sicurezza. Generazione file statico in formato Excel da conservare server-side. Operazione a bassa priorità da accodare ai job notturni o weekend. Serve solo per compliance e non per attività correnti. con condizioni commerciali - disponibilità - bug
# TEXT_CLEAN: errore calcolo iva importo errato su fattura estera non validabile con bug con login fallito memory leak procedura di backup storico export fatture anno 2015 per archivio sicurezza generazione file statico in formato excel da conservare server side operazione a bassa priorità da accodare ai job notturni o weekend serve solo per compliance e non per attività correnti con condizioni commerciali disponibilità bug
#
# --- Ticket 4 ---
# TEXT      : Blocco sistema durante elaborazione fattura 8373/22 per Righi, Federici e Morosini e figli con performance Attività di background: archiviazione documenti storici cliente Righi, Federici e Morosini e filgi per anno 2022. Si tratta di spostare vecchi file (fatture, contratti) nell'archivio morto per liberare spazio. Nessuna urgenza operativa: il task può girare nei momenti di inattività del sistema. Operazione di manutenzione ordinaria del database.
# TEXT_CLEAN: blocco sistema durante elaborazione fattura 8373 22 per righi federici e morosini e figli con performance attività di background archiviazione documenti storici cliente righi federici e morosini e filgi per anno 2022 si tratta di spostare vecchi file fatture contratti nell archivio morto per liberare spazio nessuna urgenza operativa il task può girare nei momenti di inattività del sistema operazione di manutenzione ordinaria del database

# %% [markdown]
# ## 5. Analisi delle lunghezze dei testi
#
# Analisi la lunghezza dei testi (in parole) prima e dopo la pulizia al fine di capire quanto contesto avranno a disposizione i modelli

# %%
# numero di parole prima e dopo la pulizia
df["len_words_raw"] = df["text"].str.split().str.len()
df["len_words_clean"] = df["text_clean"].str.split().str.len()

summary = df[["len_words_raw", "len_words_clean"]].describe().T
print(summary)

# controllo ticket estremamente corti
print("\nEsempi di ticket molto corti (<= 3 parole pulite):\n")
short_mask = df["len_words_clean"] <= 3
df[short_mask][["id", "text", "text_clean", "len_words_clean"]].head(10)
# Out:
#                  count       mean       std   min   25%   50%   75%   max
# len_words_raw    480.0  47.231250  7.492979  31.0  42.0  46.5  52.0  72.0
# len_words_clean  480.0  48.364583  7.962228  32.0  42.0  47.0  54.0  75.0
#
# Esempi di ticket molto corti (<= 3 parole pulite):
# Empty DataFrame
# Columns: [id, text, text_clean, len_words_clean]
# Index: []

# %% [markdown]
# ## 6. Suddivisione train/test
#
# Utilizzo di `train_test_split` scikit-learn per dividere il dataset in due parti (training set e test set) sul testo grezzo (`text`) e sulle etichette:
#
# - `category` (classificazione della tipologia di ticket)
# - `priority` (bassa / media / alta)
#
# Uso di `stratify` sulla categoria per mantenere una distribuzione simile nel train e nel test.

# %%
 # Controllo che le colonne target esistano
for col in ["category", "priority"]:
    if col not in df.columns:
        raise ValueError(f"La colonna target '{col}' non esiste nel dataset. Controlla il generatore di dataset.")

X = df["text"] 

y_cat = df["category"]
y_pri = df["priority"]

X_train, X_test, y_cat_train, y_cat_test = train_test_split(
    X,
    y_cat,
    test_size=0.2,
    random_state=42,
    stratify=y_cat
)

# riallineo anche le priorità usando gli indici
y_pri_train = df.loc[X_train.index, "priority"]
y_pri_test  = df.loc[X_test.index,  "priority"]

print("Dimensioni train/test:")
print("X_train:", X_train.shape[0])
print("X_test :", X_test.shape[0])
# Out:
# Dimensioni train/test:
# X_train: 384
# X_test : 96

# %% [markdown]
# ## 7. Controllo della distribuzione delle classi
#
# Verifica della distribuzione categorie affinchè sia simile nel dataset completo, nel train e nel test.

# %%
def print_distribution_and_counts(label, series_full, series_train, series_test):
    """Stampa distribuzioni percentuali e conteggi assoluti per full/train/test di una variabile target."""
    
    datasets = {
        "full" : series_full,
        "train": series_train,
        "test" : series_test
    }
    
    print(f"\n=== {label.upper()} ===")

    # Distribuzioni percentuali
    print("\nDistribuzioni percentuali (%):")
    for name, s in datasets.items():
        perc = s.value_counts(normalize=True).mul(100).round(2)
        print(f"\n{name}:")
        print(perc)

    # Conteggi assoluti
    print("\nConteggi assoluti:")
    for name, s in datasets.items():
        print(f"\n{name}:")
        print(s.value_counts())


# Uso della funzione
print_distribution_and_counts("Category", y_cat, y_cat_train, y_cat_test)
print_distribution_and_counts("Priority", y_pri, y_pri_train, y_pri_test)
# Out:
# === CATEGORY ===
#
# Distribuzioni percentuali (%):
#
# full:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# train:
# category
# Tecnico            45.05
# Amministrazione    29.95
# Commerciale        25.00
# Name: proportion, dtype: float64
#
# test:
# category
# Tecnico            44.79
# Amministrazione    30.21
# Commerciale        25.00
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# category
# Tecnico            216
# Amministrazione    144
# Commerciale        120
# Name: count, dtype: int64
#
# train:
# category
# Tecnico            173
# Amministrazione    115
# Commerciale         96
# Name: count, dtype: int64
#
# test:
# category
# Tecnico            43
# Amministrazione    29
# Commerciale        24
# Name: count, dtype: int64
#
# === PRIORITY ===
#
# Distribuzioni percentuali (%):
#
# full:
# priority
# media    37.29
# alta     33.54
# bassa    29.17
# Name: proportion, dtype: float64
#
# train:
# priority
# media    38.28
# alta     33.07
# bassa    28.65
# Name: proportion, dtype: float64
#
# test:
# priority
# alta     35.42
# media    33.33
# bassa    31.25
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# priority
# media    179
# alta     161
# bassa    140
# Name: count, dtype: int64
#
# train:
# priority
# media    147
# alta     127
# bassa    110
# Name: count, dtype: int64
#
# test:
# priority
# alta     34
# media    32
# bassa    30
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Salvataggio del dataset con indicazione train/test
#
# Viene aggiunta una colonna `split` al DataFrame (`train` / `test`) e salvato un CSV aggiornato, che sarà il punto di partenza per EDA e training.

# %%
# inizialmente tutto train
df["split"] = "train"

# assegno 'test' alle righe presenti in X_test
df.loc[X_test.index, "split"] = "test"

print(df["split"].value_counts())

# TODO: adatta il path/output
output_path = DATA_DIR / "splits" / "tickets_preprocessed_split.csv"
df.to_csv(output_path, index=False)
print(f"\nFile salvato in: {output_path}")
# Out:
# split
# train    384
# test      96
# Name: count, dtype: int64
#
# File salvato in: C:\project-work\data\splits\tickets_preprocessed_split.csv
