# %% [markdown]
# # Preprocessing NLP per ticket di supporto
#
# In questo notebook vengono preparati i dati testuali dei ticket per l'addestramento dei modelli di classificazione:
# - costruzione del campo testuale (oggetto + descrizione)
# - pulizia testuale semplice e riproducibile
# - analisi di base delle lunghezze
# - suddivisione train/test senza leakage

# %%
import pandas as pd
import re

from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"

from sklearn.model_selection import train_test_split

pd.set_option("display.max_colwidth", 200)

df = pd.read_csv(DATA_DIR / "raw" / "tickets_realistic.csv")

print("Shape iniziale:", df.shape)
df.head()
# Out:
# Shape iniziale: (4800, 7)
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                      title  \
# 0  Mancata notifica: email approvazione persa (processo fermo) con listino
# 1                                   Manutenzione: pulizia account inattivi
# 2                          Funzione rotta: tasto upload PDF non cliccabile
# 3             Monitoraggio: log modulo utenti (nessun errore) - preventivo
# 4                                             Backup: storico fatture 1986
#
#                                                                                                                                                                                                       body  \
# 0  Mancato allineamento incassi: il bonifico di 117.31 non risulta in contabilità. In banca è presente, ma il modulo reportistica non lo ha importato automaticamente. Necsesario inserimento manuale o...
# 1  Procedura di backup storico: expotr fatture anno 1989 per archivio sicurezza. Generazione file statcio in formato Excel da conservare server-side. Operazione a bassa priorità da accodare ai job no...
# 2  L'account utente admin_01 risulta bloccato dal sys. catalogo con errore "ERR_TIMEOUT". L'utente deve urgentemente accedere per completare l'elaborazione delle fatture per il cliente Vittadello, Ni...
# 3  Controlol qualità dati cnotabili storici per archivio. Verifica di routine sulla coerenza dei vecchi movimenti di anni passati. Non blocca nessuna attività corrente e non richiede correzioni urgen...
# 4  Procedura di backup storico: export fatture anno 1986 per archivio sicurezza. Generazione file statico in formato CSV da conservare server-side. Operazione a bassa priorità da accodare ai job nott...
#
#           category priority  title_length  body_length
# 0  Amministrazione    media            71          350
# 1  Amministrazione    bassa            38          268
# 2  Amministrazione     alta            47          426
# 3  Amministrazione    media            60          266
# 4  Amministrazione    bassa            28          267

# %% [markdown]
# ## 2. Costruzione del campo testuale unico
#
# Vengono uniti oggetto e descrizione del ticket in un singolo campo `text`, che sarà utilizzato come input testuale per tutti i modelli.

# %%
TITLE_COL = "title"      
BODY_COL  = "body"       

# Controllo che le colonne esistano
print("Colonne presenti:", df.columns.tolist())
if TITLE_COL not in df.columns or BODY_COL not in df.columns:
    raise ValueError(f"Le colonne {TITLE_COL} e/o {BODY_COL} non esistono nel dataset. Adattale prima di proseguire.")

# Costruzione del campo testuale
df["text"] = (
    df[TITLE_COL].fillna("").astype(str) + " " + df[BODY_COL].fillna("").astype(str)
).str.strip()

# Rimuovo righe con testo completamente vuoto
before = df.shape[0]
df = df[df["text"].str.len() > 0].copy()
after = df.shape[0]

print(f"Righe totali dopo rimozione testi vuoti: {after} (rimosse {before - after})")
df[["id", TITLE_COL, BODY_COL, "text"]].head()
# Out:
# Colonne presenti: ['id', 'title', 'body', 'category', 'priority', 'title_length', 'body_length']
# Righe totali dopo rimozione testi vuoti: 4800 (rimosse 0)
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                      title  \
# 0  Mancata notifica: email approvazione persa (processo fermo) con listino
# 1                                   Manutenzione: pulizia account inattivi
# 2                          Funzione rotta: tasto upload PDF non cliccabile
# 3             Monitoraggio: log modulo utenti (nessun errore) - preventivo
# 4                                             Backup: storico fatture 1986
#
#                                                                                                                                                                                                       body  \
# 0  Mancato allineamento incassi: il bonifico di 117.31 non risulta in contabilità. In banca è presente, ma il modulo reportistica non lo ha importato automaticamente. Necsesario inserimento manuale o...
# 1  Procedura di backup storico: expotr fatture anno 1989 per archivio sicurezza. Generazione file statcio in formato Excel da conservare server-side. Operazione a bassa priorità da accodare ai job no...
# 2  L'account utente admin_01 risulta bloccato dal sys. catalogo con errore "ERR_TIMEOUT". L'utente deve urgentemente accedere per completare l'elaborazione delle fatture per il cliente Vittadello, Ni...
# 3  Controlol qualità dati cnotabili storici per archivio. Verifica di routine sulla coerenza dei vecchi movimenti di anni passati. Non blocca nessuna attività corrente e non richiede correzioni urgen...
# 4  Procedura di backup storico: export fatture anno 1986 per archivio sicurezza. Generazione file statico in formato CSV da conservare server-side. Operazione a bassa priorità da accodare ai job nott...
#
#                                                                                                                                                                                                       text
# 0  Mancata notifica: email approvazione persa (processo fermo) con listino Mancato allineamento incassi: il bonifico di 117.31 non risulta in contabilità. In banca è presente, ma il modulo reportisti...
# 1  Manutenzione: pulizia account inattivi Procedura di backup storico: expotr fatture anno 1989 per archivio sicurezza. Generazione file statcio in formato Excel da conservare server-side. Operazione...
# 2  Funzione rotta: tasto upload PDF non cliccabile L'account utente admin_01 risulta bloccato dal sys. catalogo con errore "ERR_TIMEOUT". L'utente deve urgentemente accedere per completare l'elaboraz...
# 3  Monitoraggio: log modulo utenti (nessun errore) - preventivo Controlol qualità dati cnotabili storici per archivio. Verifica di routine sulla coerenza dei vecchi movimenti di anni passati. Non blo...
# 4  Backup: storico fatture 1986 Procedura di backup storico: export fatture anno 1986 per archivio sicurezza. Generazione file statico in formato CSV da conservare server-side. Operazione a bassa pri...

# %% [markdown]
# ## 3. Pulizia testuale semplice
#
# Viene definita una funzione `clean_text` che applica:
#
# - conversione in minuscolo
# - rimozione dei simboli non utili
# - normalizzazione degli spazi

# %%
def clean_text(text: str) -> str:
    if not isinstance(text, str):
        text = "" if text is None else str(text)
        
    # minuscole (e togli lowercase=False dal TFIDF)
    text = text.lower()
    
    # rimuovi solo simboli non utili
    text = re.sub(r"[^\w\sàèéìòù]", " ", text)
    
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Test veloce della funzione su un esempio
example = "URGENTE: Fattura 12345 non pagata!!!"
print("Originale:", example)
print("Pulito   :", clean_text(example))
# Out:
# Originale: URGENTE: Fattura 12345 non pagata!!!
# Pulito   : urgente fattura 12345 non pagata

# %% [markdown]
# ## 4. Applicazione della pulizia e controlli di base
#
# Applicazione di `clean_text` al campo `text` per ottenere `text_clean` e verifica dei primi 5 record prima/dopo

# %%
df["text_clean"] = df["text"].apply(clean_text)

print("Esempi di testo prima/dopo:\n")
for i in range(5):
    print(f"--- Ticket {i} ---")
    print("TEXT      :", df.iloc[i]["text"])
    print("TEXT_CLEAN:", df.iloc[i]["text_clean"])
    print()
# Out:
# Esempi di testo prima/dopo:
#
# --- Ticket 0 ---
# TEXT      : Mancata notifica: email approvazione persa (processo fermo) con listino Mancato allineamento incassi: il bonifico di 117.31 non risulta in contabilità. In banca è presente, ma il modulo reportistica non lo ha importato automaticamente. Necsesario inserimento manuale o forzatura sync per chiudere la posizione del cliente Benussi-Curiel Group. Il problema riguarda solo i bonifici di ieri. per memory leak con memory leaka
# TEXT_CLEAN: mancata notifica email approvazione persa processo fermo con listino mancato allineamento incassi il bonifico di 117 31 non risulta in contabilità in banca è presente ma il modulo reportistica non lo ha importato automaticamente necsesario inserimento manuale o forzatura sync per chiudere la posizione del cliente benussi curiel group il problema riguarda solo i bonifici di ieri per memory leak con memory leaka
#
# --- Ticket 1 ---
# TEXT      : Manutenzione: pulizia account inattivi Procedura di backup storico: expotr fatture anno 1989 per archivio sicurezza. Generazione file statcio in formato Excel da conservare server-side. Operazione a bassa priorità da accodare ai job notturni o weekend. Serve solo per compliance e non per attività correnti.
# TEXT_CLEAN: manutenzione pulizia account inattivi procedura di backup storico expotr fatture anno 1989 per archivio sicurezza generazione file statcio in formato excel da conservare server side operazione a bassa priorità da accodare ai job notturni o weekend serve solo per compliance e non per attività correnti
#
# --- Ticket 2 ---
# TEXT      : Funzione rotta: tasto upload PDF non cliccabile L'account utente admin_01 risulta bloccato dal sys. catalogo con errore "ERR_TIMEOUT". L'utente deve urgentemente accedere per completare l'elaborazione delle fatture per il cliente Vittadello, Niscoromni e Boldù Group. Il blocco sta impattando le operazioni di chiusura ordini e l'invio documenti contabili. Si richiede intervento tecnico immediato per ripristino accesso entro in giornata. condizioni commerciali performance
# TEXT_CLEAN: funzione rotta tasto upload pdf non cliccabile l account utente admin_01 risulta bloccato dal sys catalogo con errore err_timeout l utente deve urgentemente accedere per completare l elaborazione delle fatture per il cliente vittadello niscoromni e boldù group il blocco sta impattando le operazioni di chiusura ordini e l invio documenti contabili si richiede intervento tecnico immediato per ripristino accesso entro in giornata condizioni commerciali performance
#
# --- Ticket 3 ---
# TEXT      : Monitoraggio: log modulo utenti (nessun errore) - preventivo Controlol qualità dati cnotabili storici per archivio. Verifica di routine sulla coerenza dei vecchi movimenti di anni passati. Non blocca nessuna attività corrente e non richiede correzioni urgenti. Si può procedere gradualmente alla validazione dei record passati.
# TEXT_CLEAN: monitoraggio log modulo utenti nessun errore preventivo controlol qualità dati cnotabili storici per archivio verifica di routine sulla coerenza dei vecchi movimenti di anni passati non blocca nessuna attività corrente e non richiede correzioni urgenti si può procedere gradualmente alla validazione dei record passati
#
# --- Ticket 4 ---
# TEXT      : Backup: storico fatture 1986 Procedura di backup storico: export fatture anno 1986 per archivio sicurezza. Generazione file statico in formato CSV da conservare server-side. Operazione a bassa priorità da accodare ai job notturni o weekend. Serve solo per compliance e non per attività correnti.a
# TEXT_CLEAN: backup storico fatture 1986 procedura di backup storico export fatture anno 1986 per archivio sicurezza generazione file statico in formato csv da conservare server side operazione a bassa priorità da accodare ai job notturni o weekend serve solo per compliance e non per attività correnti a

# %% [markdown]
# ## 5. Analisi delle lunghezze dei testi
#
# Analisi la lunghezza dei testi (in parole) prima e dopo la pulizia al fine di capire quanto contesto avranno a disposizione i modelli

# %%
# numero di parole prima e dopo la pulizia
df["len_words_raw"] = df["text"].str.split().str.len()
df["len_words_clean"] = df["text_clean"].str.split().str.len()

summary = df[["len_words_raw", "len_words_clean"]].describe().T
print(summary)

# controllo ticket estremamente corti
print("\nEsempi di ticket molto corti (<= 3 parole pulite):\n")
short_mask = df["len_words_clean"] <= 3
df[short_mask][["id", "text", "text_clean", "len_words_clean"]].head(10)
# Out:
#                   count       mean       std   min   25%   50%   75%   max
# len_words_raw    4800.0  46.685208  7.260683  30.0  41.0  46.0  51.0  74.0
# len_words_clean  4800.0  47.716458  7.618031  30.0  42.0  47.0  53.0  81.0
#
# Esempi di ticket molto corti (<= 3 parole pulite):
# Empty DataFrame
# Columns: [id, text, text_clean, len_words_clean]
# Index: []

# %% [markdown]
# ## 6. Suddivisione train/test
#
# Utilizzo di `train_test_split` scikit-learn per dividere il dataset in due parti (training set e test set) sul testo grezzo (`text`) e sulle etichette:
#
# - `category` (classificazione della tipologia di ticket)
# - `priority` (bassa / media / alta)
#
# Uso di `stratify` sulla categoria per mantenere una distribuzione simile nel train e nel test.

# %%
 # Controllo che le colonne target esistano
for col in ["category", "priority"]:
    if col not in df.columns:
        raise ValueError(f"La colonna target '{col}' non esiste nel dataset. Controlla il generatore di dataset.")

X = df["text"] 

y_cat = df["category"]
y_pri = df["priority"]

X_train, X_test, y_cat_train, y_cat_test = train_test_split(
    X,
    y_cat,
    test_size=0.2,
    random_state=42,
    stratify=y_cat
)

# riallineo anche le priorità usando gli indici
y_pri_train = df.loc[X_train.index, "priority"]
y_pri_test  = df.loc[X_test.index,  "priority"]

print("Dimensioni train/test:")
print("X_train:", X_train.shape[0])
print("X_test :", X_test.shape[0])
# Out:
# Dimensioni train/test:
# X_train: 3840
# X_test : 960

# %% [markdown]
# ## 7. Controllo della distribuzione delle classi
#
# Verifica della distribuzione categorie affinchè sia simile nel dataset completo, nel train e nel test.

# %%
def print_distribution_and_counts(label, series_full, series_train, series_test):
    """Stampa distribuzioni percentuali e conteggi assoluti per full/train/test di una variabile target."""
    
    datasets = {
        "full" : series_full,
        "train": series_train,
        "test" : series_test
    }
    
    print(f"\n=== {label.upper()} ===")

    # Distribuzioni percentuali
    print("\nDistribuzioni percentuali (%):")
    for name, s in datasets.items():
        perc = s.value_counts(normalize=True).mul(100).round(2)
        print(f"\n{name}:")
        print(perc)

    # Conteggi assoluti
    print("\nConteggi assoluti:")
    for name, s in datasets.items():
        print(f"\n{name}:")
        print(s.value_counts())


# Uso della funzione
print_distribution_and_counts("Category", y_cat, y_cat_train, y_cat_test)
print_distribution_and_counts("Priority", y_pri, y_pri_train, y_pri_test)
# Out:
# === CATEGORY ===
#
# Distribuzioni percentuali (%):
#
# full:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# train:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# test:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# category
# Tecnico            2160
# Amministrazione    1440
# Commerciale        1200
# Name: count, dtype: int64
#
# train:
# category
# Tecnico            1728
# Amministrazione    1152
# Commerciale         960
# Name: count, dtype: int64
#
# test:
# category
# Tecnico            432
# Amministrazione    288
# Commerciale        240
# Name: count, dtype: int64
#
# === PRIORITY ===
#
# Distribuzioni percentuali (%):
#
# full:
# priority
# media    38.90
# alta     32.06
# bassa    29.04
# Name: proportion, dtype: float64
#
# train:
# priority
# media    39.48
# alta     32.21
# bassa    28.31
# Name: proportion, dtype: float64
#
# test:
# priority
# media    36.56
# bassa    31.98
# alta     31.46
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# priority
# media    1867
# alta     1539
# bassa    1394
# Name: count, dtype: int64
#
# train:
# priority
# media    1516
# alta     1237
# bassa    1087
# Name: count, dtype: int64
#
# test:
# priority
# media    351
# bassa    307
# alta     302
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Salvataggio del dataset con indicazione train/test
#
# Viene aggiunta una colonna `split` al DataFrame (`train` / `test`) e salvato un CSV aggiornato, che sarà il punto di partenza per EDA e training.

# %%
# inizialmente tutto train
df["split"] = "train"

# assegno 'test' alle righe presenti in X_test
df.loc[X_test.index, "split"] = "test"

print(df["split"].value_counts())

# TODO: adatta il path/output
output_path = DATA_DIR / "splits" / "tickets_preprocessed_split.csv"
df.to_csv(output_path, index=False)
print(f"\nFile salvato in: {output_path}")
# Out:
# split
# train    3840
# test      960
# Name: count, dtype: int64
# File salvato in: C:\project-work\data\splits\tickets_preprocessed_split.csv
