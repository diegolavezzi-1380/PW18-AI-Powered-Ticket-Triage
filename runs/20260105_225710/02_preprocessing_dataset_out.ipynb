# %% [markdown]
# # Preprocessing NLP per ticket di supporto
#
# In questo notebook vengono preparati i dati testuali dei ticket per l'addestramento dei modelli di classificazione:
# - costruzione del campo testuale (oggetto + descrizione)
# - pulizia testuale semplice e riproducibile
# - analisi di base delle lunghezze
# - suddivisione train/test senza leakage

# %%
import pandas as pd
import re

from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"

from sklearn.model_selection import train_test_split

pd.set_option("display.max_colwidth", 200)

df = pd.read_csv(DATA_DIR / "raw" / "tickets_realistic.csv")

print("Shape iniziale:", df.shape)
df.head()
# Out:
# Shape iniziale: (4800, 7)
#    id  title  \
# 0   1    NaN
# 1   2    NaN
# 2   3    NaN
# 3   4    NaN
# 4   5    NaN
#
#                                                                                                                                                                                                       body  \
# 0  problem validazione codice fiscale per nuovo cliente Pagliaro-Corcos SPA. Il system lo esgna come errato anche se è formalmente valido. Impedisce il salvataggio della scheda cliente. Necessario by...
# 1  Data entry: modifica schead informativa cliente Dossi-Benussi SPA. Aggiornamento campi email amanda06@bacosi-vitturi.it e referente mario.rossi. Modifica puramente formale per completezza anagrafi...
# 2  Richiesta estrazione dati statistici su utilizzo licenze Linea Accessori. Il report serve esclusivamente per proiezioni di budgte anno prossimo (uso interno). Nessuna scadenza operatiav immediata....
# 3  Duplicazione righe in visualizzazione estratto conto Mezzetta-Caracciolo SPA. Le fatture appaiono due volte nella lista a video. Il saldo finale è corretto, è solo un errore visivo che confonde gl...
# 4  Richiesta estrazione dati statistici su utilizzo licenze Linea acc.ri. Il report serve esclusivamente per proiezioni di budget anno prossimo (uso interno). Nessuna scadenza operativa immediata. El...
#
#           category priority  title_length  body_length
# 0  Amministrazione    media             0          257
# 1  Amministrazione    bassa             0          296
# 2  Amministrazione     alta             0          298
# 3  Amministrazione    media             0          323
# 4  Amministrazione    bassa             0          277

# %% [markdown]
# ## 2. Costruzione del campo testuale unico
#
# Vengono uniti oggetto e descrizione del ticket in un singolo campo `text`, che sarà utilizzato come input testuale per tutti i modelli.

# %%
TITLE_COL = "title"      
BODY_COL  = "body"       

# Controllo che le colonne esistano
print("Colonne presenti:", df.columns.tolist())
if TITLE_COL not in df.columns or BODY_COL not in df.columns:
    raise ValueError(f"Le colonne {TITLE_COL} e/o {BODY_COL} non esistono nel dataset. Adattale prima di proseguire.")

# Costruzione del campo testuale
df["text"] = (
    df[TITLE_COL].fillna("").astype(str) + " " + df[BODY_COL].fillna("").astype(str)
).str.strip()

# Rimuovo righe con testo completamente vuoto
before = df.shape[0]
df = df[df["text"].str.len() > 0].copy()
after = df.shape[0]

print(f"Righe totali dopo rimozione testi vuoti: {after} (rimosse {before - after})")
df[["id", TITLE_COL, BODY_COL, "text"]].head()
# Out:
# Colonne presenti: ['id', 'title', 'body', 'category', 'priority', 'title_length', 'body_length']
# Righe totali dopo rimozione testi vuoti: 4800 (rimosse 0)
#    id  title  \
# 0   1    NaN
# 1   2    NaN
# 2   3    NaN
# 3   4    NaN
# 4   5    NaN
#
#                                                                                                                                                                                                       body  \
# 0  problem validazione codice fiscale per nuovo cliente Pagliaro-Corcos SPA. Il system lo esgna come errato anche se è formalmente valido. Impedisce il salvataggio della scheda cliente. Necessario by...
# 1  Data entry: modifica schead informativa cliente Dossi-Benussi SPA. Aggiornamento campi email amanda06@bacosi-vitturi.it e referente mario.rossi. Modifica puramente formale per completezza anagrafi...
# 2  Richiesta estrazione dati statistici su utilizzo licenze Linea Accessori. Il report serve esclusivamente per proiezioni di budgte anno prossimo (uso interno). Nessuna scadenza operatiav immediata....
# 3  Duplicazione righe in visualizzazione estratto conto Mezzetta-Caracciolo SPA. Le fatture appaiono due volte nella lista a video. Il saldo finale è corretto, è solo un errore visivo che confonde gl...
# 4  Richiesta estrazione dati statistici su utilizzo licenze Linea acc.ri. Il report serve esclusivamente per proiezioni di budget anno prossimo (uso interno). Nessuna scadenza operativa immediata. El...
#
#                                                                                                                                                                                                       text
# 0  problem validazione codice fiscale per nuovo cliente Pagliaro-Corcos SPA. Il system lo esgna come errato anche se è formalmente valido. Impedisce il salvataggio della scheda cliente. Necessario by...
# 1  Data entry: modifica schead informativa cliente Dossi-Benussi SPA. Aggiornamento campi email amanda06@bacosi-vitturi.it e referente mario.rossi. Modifica puramente formale per completezza anagrafi...
# 2  Richiesta estrazione dati statistici su utilizzo licenze Linea Accessori. Il report serve esclusivamente per proiezioni di budgte anno prossimo (uso interno). Nessuna scadenza operatiav immediata....
# 3  Duplicazione righe in visualizzazione estratto conto Mezzetta-Caracciolo SPA. Le fatture appaiono due volte nella lista a video. Il saldo finale è corretto, è solo un errore visivo che confonde gl...
# 4  Richiesta estrazione dati statistici su utilizzo licenze Linea acc.ri. Il report serve esclusivamente per proiezioni di budget anno prossimo (uso interno). Nessuna scadenza operativa immediata. El...

# %% [markdown]
# ## 3. Pulizia testuale semplice
#
# Viene definita una funzione `clean_text` che applica:
#
# - conversione in minuscolo
# - rimozione dei simboli non utili
# - normalizzazione degli spazi

# %%
def clean_text(text: str) -> str:
    if not isinstance(text, str):
        text = "" if text is None else str(text)
        
    # minuscole 
    text = text.lower()
    
    # rimuovi solo simboli non utili
    text = re.sub(r"[^\w\sàèéìòù]", " ", text)
    
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Test veloce della funzione su un esempio
example = "URGENTE: Fattura 12345 non pagata!!!"
print("Originale:", example)
print("Pulito   :", clean_text(example))
# Out:
# Originale: URGENTE: Fattura 12345 non pagata!!!
# Pulito   : urgente fattura 12345 non pagata

# %% [markdown]
# ## 4. Applicazione della pulizia e controlli di base
#
# Applicazione di `clean_text` al campo `text` per ottenere `text_clean` e verifica dei primi 5 record prima/dopo

# %%
df["text_clean"] = df["text"].apply(clean_text)

print("Esempi di testo prima/dopo:\n")
for i in range(5):
    print(f"--- Ticket {i} ---")
    print("TEXT      :", df.iloc[i]["text"])
    print("TEXT_CLEAN:", df.iloc[i]["text_clean"])
    print()
# Out:
# Esempi di testo prima/dopo:
#
# --- Ticket 0 ---
# TEXT      : problem validazione codice fiscale per nuovo cliente Pagliaro-Corcos SPA. Il system lo esgna come errato anche se è formalmente valido. Impedisce il salvataggio della scheda cliente. Necessario bypassare il controllo o correggere l'algoritmo di validazione.
# TEXT_CLEAN: problem validazione codice fiscale per nuovo cliente pagliaro corcos spa il system lo esgna come errato anche se è formalmente valido impedisce il salvataggio della scheda cliente necessario bypassare il controllo o correggere l algoritmo di validazione
#
# --- Ticket 1 ---
# TEXT      : Data entry: modifica schead informativa cliente Dossi-Benussi SPA. Aggiornamento campi email amanda06@bacosi-vitturi.it e referente mario.rossi. Modifica puramente formale per completezza anagrafica. Attività amministrativa standard di basso livello, gestibile in background. con sincronizzazione
# TEXT_CLEAN: data entry modifica schead informativa cliente dossi benussi spa aggiornamento campi email amanda06 bacosi vitturi it e referente mario rossi modifica puramente formale per completezza anagrafica attività amministrativa standard di basso livello gestibile in background con sincronizzazione
#
# --- Ticket 2 ---
# TEXT      : Richiesta estrazione dati statistici su utilizzo licenze Linea Accessori. Il report serve esclusivamente per proiezioni di budgte anno prossimo (uso interno). Nessuna scadenza operatiav immediata. lEaborazione da fare offline quando le risorse lo permettono. condizioni commerciali - errore critico
# TEXT_CLEAN: richiesta estrazione dati statistici su utilizzo licenze linea accessori il report serve esclusivamente per proiezioni di budgte anno prossimo uso interno nessuna scadenza operatiav immediata leaborazione da fare offline quando le risorse lo permettono condizioni commerciali errore critico
#
# --- Ticket 3 ---
# TEXT      : Duplicazione righe in visualizzazione estratto conto Mezzetta-Caracciolo SPA. Le fatture appaiono due volte nella lista a video. Il saldo finale è corretto, è solo un errore visivo che confonde gli operatori. Richiesta pulizia della view nel modulo reportistica., problema su account con negoziazione sconto - login fallito
# TEXT_CLEAN: duplicazione righe in visualizzazione estratto conto mezzetta caracciolo spa le fatture appaiono due volte nella lista a video il saldo finale è corretto è solo un errore visivo che confonde gli operatori richiesta pulizia della view nel modulo reportistica problema su account con negoziazione sconto login fallito
#
# --- Ticket 4 ---
# TEXT      : Richiesta estrazione dati statistici su utilizzo licenze Linea acc.ri. Il report serve esclusivamente per proiezioni di budget anno prossimo (uso interno). Nessuna scadenza operativa immediata. Elaborazione da fare offline quando le risorse lo permettono.  [vedi nota allegata]
# TEXT_CLEAN: richiesta estrazione dati statistici su utilizzo licenze linea acc ri il report serve esclusivamente per proiezioni di budget anno prossimo uso interno nessuna scadenza operativa immediata elaborazione da fare offline quando le risorse lo permettono vedi nota allegata

# %% [markdown]
# ## 5. Analisi delle lunghezze dei testi
#
# Analisi la lunghezza dei testi (in parole) prima e dopo la pulizia al fine di capire quanto contesto avranno a disposizione i modelli

# %%
# numero di parole prima e dopo la pulizia
df["len_words_raw"] = df["text"].str.split().str.len()
df["len_words_clean"] = df["text_clean"].str.split().str.len()

summary = df[["len_words_raw", "len_words_clean"]].describe().T
print(summary)

# controllo ticket estremamente corti
print("\nEsempi di ticket molto corti (<= 3 parole pulite):\n")
short_mask = df["len_words_clean"] <= 3
df[short_mask][["id", "text", "text_clean", "len_words_clean"]].head(10)
# Out:
#                   count       mean       std   min   25%   50%   75%   max
# len_words_raw    4800.0  39.215833  6.568922  26.0  34.0  38.0  44.0  63.0
# len_words_clean  4800.0  40.426042  7.124408  26.0  35.0  39.0  45.0  69.0
# Esempi di ticket molto corti (<= 3 parole pulite):
# Empty DataFrame
# Columns: [id, text, text_clean, len_words_clean]
# Index: []

# %% [markdown]
# ## 6. Suddivisione train/test
#
# Utilizzo di `train_test_split` scikit-learn per dividere il dataset in due parti (training set e test set) sul testo grezzo (`text`) e sulle etichette:
#
# - `category` (classificazione della tipologia di ticket)
# - `priority` (bassa / media / alta)
#
# Uso di `stratify` sulla combinazione di categoria e priorità per mantenere una distribuzione simile nel train e nel test.

# %%
 # Controllo che le colonne target esistano
for col in ["category", "priority"]:
    if col not in df.columns:
        raise ValueError(f"La colonna target '{col}' non esiste nel dataset. Controlla il generatore di dataset.")

X = df["text"] 

y_cat = df["category"]
y_pri = df["priority"]
strat = df["category"].astype(str) + "||" + df["priority"].astype(str)

X_train, X_test, y_cat_train, y_cat_test = train_test_split(
    X,
    y_cat,
    test_size=0.2,
    random_state=42,
    stratify=strat
)

# riallineo anche le priorità usando gli indici
y_pri_train = df.loc[X_train.index, "priority"]
y_pri_test  = df.loc[X_test.index,  "priority"]

print("Dimensioni train/test:")
print("X_train:", X_train.shape[0])
print("X_test :", X_test.shape[0])
# Out:
# Dimensioni train/test:
# X_train: 3840
# X_test : 960

# %% [markdown]
# ## 7. Controllo della distribuzione delle classi
#
# Verifica della distribuzione categorie affinchè sia simile nel dataset completo, nel train e nel test.

# %%
def print_distribution_and_counts(label, series_full, series_train, series_test):
    """Stampa distribuzioni percentuali e conteggi assoluti per full/train/test di una variabile target."""
    
    datasets = {
        "full" : series_full,
        "train": series_train,
        "test" : series_test
    }
    
    print(f"\n=== {label.upper()} ===")

    # Distribuzioni percentuali
    print("\nDistribuzioni percentuali (%):")
    for name, s in datasets.items():
        perc = s.value_counts(normalize=True).mul(100).round(2)
        print(f"\n{name}:")
        print(perc)

    # Conteggi assoluti
    print("\nConteggi assoluti:")
    for name, s in datasets.items():
        print(f"\n{name}:")
        print(s.value_counts())


# Uso della funzione
print_distribution_and_counts("Category", y_cat, y_cat_train, y_cat_test)
print_distribution_and_counts("Priority", y_pri, y_pri_train, y_pri_test)
# Out:
# === CATEGORY ===
#
# Distribuzioni percentuali (%):
#
# full:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# train:
# category
# Tecnico            45.00
# Amministrazione    29.97
# Commerciale        25.03
# Name: proportion, dtype: float64
#
# test:
# category
# Tecnico            45.0
# Amministrazione    30.1
# Commerciale        24.9
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# category
# Tecnico            2160
# Amministrazione    1440
# Commerciale        1200
# Name: count, dtype: int64
#
# train:
# category
# Tecnico            1728
# Amministrazione    1151
# Commerciale         961
# Name: count, dtype: int64
#
# test:
# category
# Tecnico            432
# Amministrazione    289
# Commerciale        239
# Name: count, dtype: int64
#
# === PRIORITY ===
#
# Distribuzioni percentuali (%):
#
# full:
# priority
# media    45.94
# bassa    29.00
# alta     25.06
# Name: proportion, dtype: float64
# train:
# priority
# media    45.94
# bassa    29.01
# alta     25.05
# Name: proportion, dtype: float64
#
# test:
# priority
# media    45.94
# bassa    28.96
# alta     25.10
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# priority
# media    2205
# bassa    1392
# alta     1203
# Name: count, dtype: int64
#
# train:
# priority
# media    1764
# bassa    1114
# alta      962
# Name: count, dtype: int64
#
# test:
# priority
# media    441
# bassa    278
# alta     241
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Salvataggio del dataset con indicazione train/test
#
# Viene aggiunta una colonna `split` al DataFrame (`train` / `test`) e salvato un CSV aggiornato, che sarà il punto di partenza per il training.

# %%
# inizialmente tutto train
df["split"] = "train"

# assegno 'test' alle righe presenti in X_test
df.loc[X_test.index, "split"] = "test"

print(df["split"].value_counts())

# TODO: adatta il path/output
output_path = DATA_DIR / "splits" / "tickets_preprocessed_split.csv"
df.to_csv(output_path, index=False)
print(f"\nFile salvato in: {output_path}")
# Out:
# split
# train    3840
# test      960
# Name: count, dtype: int64
#
# File salvato in: C:\project-work\data\splits\tickets_preprocessed_split.csv
