# %% [markdown]
# # Preprocessing NLP per ticket di supporto
#
# In questo notebook vengono preparati i dati testuali dei ticket per l'addestramento dei modelli di classificazione:
# - costruzione del campo testuale (oggetto + descrizione)
# - pulizia testuale semplice e riproducibile
# - analisi di base delle lunghezze
# - suddivisione train/test senza leakage

# %%
import pandas as pd
import re

from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"

from sklearn.model_selection import train_test_split

pd.set_option("display.max_colwidth", 200)

df = pd.read_csv(DATA_DIR / "raw" / "tickets_realistic.csv")

print("Shape iniziale:", df.shape)
df.head()
# Out:
# Shape iniziale: (480, 7)
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                                   title  \
# 0  Errore stampa: impossibile stampare fattura 9052/22 (cliente aspetta) - performance - negoziazione con login fallito
# 1                                                           Mancata notifica: email approvazione persa (processo fermo)
# 2                                                 Errore stampa: impossibile stampare fattura 9410/20 (cliente aspetta)
# 3                                                                       Monitoraggio: log modulo utenti (nessun errore)
# 4                                                         Account bloccato: utente mario.rossi fermo (troppi tentativi)
#
#                                                                                                                                                                                                       body  \
# 0  Malfunzionamento export Excel per report mensile. La generazione del file si interrompe a metà con error generico. I dati a ivdeo sono corretti. Serve il file epsortato per riunione di domani matt...
# 1  Monitoraggio passivo dei log modulo gestione utenti per statistiche utilizzo. Analisi a posteriori dei tracciati per identificare trend di lungo periodo. Non ci sono rerori attivi o malfunzionamen...
# 2  urgent completare la registrazione del pagamento per l'ordine ORD-41904 del cliente Cociarelli Group. Il sys mostra errore ERR_CONNECTION_REFUSED durante l'inserimento dell'importo 260.89 in repor...
# 3  Impossibile allegare PDF al record della fattura 8018/24. Il bottone 'Upload' non risponde o dà errroe di permessi. Il documento deve essere archiviato digitalmente entro fine mese. Problema limit...
# 4  Controllo qualità dati contabili storici per archivio. Verifica di routine sulla coerenza dei vecchi movimenti di anni passati. Non blocca nessuna attività corrente e non richiede correzioni urgen...
#
#           category priority  title_length  body_length
# 0  Amministrazione    media           116          222
# 1  Amministrazione    bassa            59          269
# 2  Amministrazione     alta            69          374
# 3  Amministrazione    media            47          243
# 4  Amministrazione     alta            61          266

# %% [markdown]
# ## 2. Costruzione del campo testuale unico
#
# Vengono uniti oggetto e descrizione del ticket in un singolo campo `text`, che sarà utilizzato come input testuale per tutti i modelli.

# %%
TITLE_COL = "title"      
BODY_COL  = "body"       

# Controllo che le colonne esistano
print("Colonne presenti:", df.columns.tolist())
if TITLE_COL not in df.columns or BODY_COL not in df.columns:
    raise ValueError(f"Le colonne {TITLE_COL} e/o {BODY_COL} non esistono nel dataset. Adattale prima di proseguire.")

# Costruzione del campo testuale
df["text"] = (
    df[TITLE_COL].fillna("").astype(str) + " " + df[BODY_COL].fillna("").astype(str)
).str.strip()

# Rimuovo righe con testo completamente vuoto
before = df.shape[0]
df = df[df["text"].str.len() > 0].copy()
after = df.shape[0]

print(f"Righe totali dopo rimozione testi vuoti: {after} (rimosse {before - after})")
df[["id", TITLE_COL, BODY_COL, "text"]].head()
# Out:
# Colonne presenti: ['id', 'title', 'body', 'category', 'priority', 'title_length', 'body_length']
# Righe totali dopo rimozione testi vuoti: 480 (rimosse 0)
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                                   title  \
# 0  Errore stampa: impossibile stampare fattura 9052/22 (cliente aspetta) - performance - negoziazione con login fallito
# 1                                                           Mancata notifica: email approvazione persa (processo fermo)
# 2                                                 Errore stampa: impossibile stampare fattura 9410/20 (cliente aspetta)
# 3                                                                       Monitoraggio: log modulo utenti (nessun errore)
# 4                                                         Account bloccato: utente mario.rossi fermo (troppi tentativi)
#
#                                                                                                                                                                                                       body  \
# 0  Malfunzionamento export Excel per report mensile. La generazione del file si interrompe a metà con error generico. I dati a ivdeo sono corretti. Serve il file epsortato per riunione di domani matt...
# 1  Monitoraggio passivo dei log modulo gestione utenti per statistiche utilizzo. Analisi a posteriori dei tracciati per identificare trend di lungo periodo. Non ci sono rerori attivi o malfunzionamen...
# 2  urgent completare la registrazione del pagamento per l'ordine ORD-41904 del cliente Cociarelli Group. Il sys mostra errore ERR_CONNECTION_REFUSED durante l'inserimento dell'importo 260.89 in repor...
# 3  Impossibile allegare PDF al record della fattura 8018/24. Il bottone 'Upload' non risponde o dà errroe di permessi. Il documento deve essere archiviato digitalmente entro fine mese. Problema limit...
# 4  Controllo qualità dati contabili storici per archivio. Verifica di routine sulla coerenza dei vecchi movimenti di anni passati. Non blocca nessuna attività corrente e non richiede correzioni urgen...
#
#                                                                                                                                                                                                       text
# 0  Errore stampa: impossibile stampare fattura 9052/22 (cliente aspetta) - performance - negoziazione con login fallito Malfunzionamento export Excel per report mensile. La generazione del file si in...
# 1  Mancata notifica: email approvazione persa (processo fermo) Monitoraggio passivo dei log modulo gestione utenti per statistiche utilizzo. Analisi a posteriori dei tracciati per identificare trend ...
# 2  Errore stampa: impossibile stampare fattura 9410/20 (cliente aspetta) urgent completare la registrazione del pagamento per l'ordine ORD-41904 del cliente Cociarelli Group. Il sys mostra errore ERR...
# 3  Monitoraggio: log modulo utenti (nessun errore) Impossibile allegare PDF al record della fattura 8018/24. Il bottone 'Upload' non risponde o dà errroe di permessi. Il documento deve essere archivi...
# 4  Account bloccato: utente mario.rossi fermo (troppi tentativi) Controllo qualità dati contabili storici per archivio. Verifica di routine sulla coerenza dei vecchi movimenti di anni passati. Non bl...

# %% [markdown]
# ## 3. Pulizia testuale semplice
#
# Viene definita una funzione `clean_text` che applica:
#
# - conversione in minuscolo
# - rimozione dei simboli non utili
# - normalizzazione degli spazi

# %%
def clean_text(text: str) -> str:
    if not isinstance(text, str):
        text = "" if text is None else str(text)
        
    # minuscole (e togli lowercase=False dal TFIDF)
    text = text.lower()
    
    # rimuovi solo simboli non utili
    text = re.sub(r"[^\w\sàèéìòù]", " ", text)
    
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Test veloce della funzione su un esempio
example = "URGENTE: Fattura 12345 non pagata!!!"
print("Originale:", example)
print("Pulito   :", clean_text(example))
# Out:
# Originale: URGENTE: Fattura 12345 non pagata!!!
# Pulito   : urgente fattura 12345 non pagata

# %% [markdown]
# ## 4. Applicazione della pulizia e controlli di base
#
# Applicazione di `clean_text` al campo `text` per ottenere `text_clean` e verifica dei primi 5 record prima/dopo

# %%
df["text_clean"] = df["text"].apply(clean_text)

print("Esempi di testo prima/dopo:\n")
for i in range(5):
    print(f"--- Ticket {i} ---")
    print("TEXT      :", df.iloc[i]["text"])
    print("TEXT_CLEAN:", df.iloc[i]["text_clean"])
    print()
# Out:
# Esempi di testo prima/dopo:
#
# --- Ticket 0 ---
# TEXT      : Errore stampa: impossibile stampare fattura 9052/22 (cliente aspetta) - performance - negoziazione con login fallito Malfunzionamento export Excel per report mensile. La generazione del file si interrompe a metà con error generico. I dati a ivdeo sono corretti. Serve il file epsortato per riunione di domani mattina. Workaround richiesto.
# TEXT_CLEAN: errore stampa impossibile stampare fattura 9052 22 cliente aspetta performance negoziazione con login fallito malfunzionamento export excel per report mensile la generazione del file si interrompe a metà con error generico i dati a ivdeo sono corretti serve il file epsortato per riunione di domani mattina workaround richiesto
#
# --- Ticket 1 ---
# TEXT      : Mancata notifica: email approvazione persa (processo fermo) Monitoraggio passivo dei log modulo gestione utenti per statistiche utilizzo. Analisi a posteriori dei tracciati per identificare trend di lungo periodo. Non ci sono rerori attivi o malfunzionamenti. Attività di studio per future ottimizzzaioni, senza impatto attuale.
# TEXT_CLEAN: mancata notifica email approvazione persa processo fermo monitoraggio passivo dei log modulo gestione utenti per statistiche utilizzo analisi a posteriori dei tracciati per identificare trend di lungo periodo non ci sono rerori attivi o malfunzionamenti attività di studio per future ottimizzzaioni senza impatto attuale
#
# --- Ticket 2 ---
# TEXT      : Errore stampa: impossibile stampare fattura 9410/20 (cliente aspetta) urgent completare la registrazione del pagamento per l'ordine ORD-41904 del cliente Cociarelli Group. Il sys mostra errore ERR_CONNECTION_REFUSED durante l'inserimento dell'importo 260.89 in reportistica. Il bonifico risulta effettuato ma il gestionale non salva i dati. Blocco critical che impedisce conferma ordine e spedizione merce. Richiesto supporto tecnico immediato.
# TEXT_CLEAN: errore stampa impossibile stampare fattura 9410 20 cliente aspetta urgent completare la registrazione del pagamento per l ordine ord 41904 del cliente cociarelli group il sys mostra errore err_connection_refused durante l inserimento dell importo 260 89 in reportistica il bonifico risulta effettuato ma il gestionale non salva i dati blocco critical che impedisce conferma ordine e spedizione merce richiesto supporto tecnico immediato
#
# --- Ticket 3 ---
# TEXT      : Monitoraggio: log modulo utenti (nessun errore) Impossibile allegare PDF al record della fattura 8018/24. Il bottone 'Upload' non risponde o dà errroe di permessi. Il documento deve essere archiviato digitalmente entro fine mese. Problema limitato alla funzione di upload, il resto funziona.
# TEXT_CLEAN: monitoraggio log modulo utenti nessun errore impossibile allegare pdf al record della fattura 8018 24 il bottone upload non risponde o dà errroe di permessi il documento deve essere archiviato digitalmente entro fine mese problema limitato alla funzione di upload il resto funziona
#
# --- Ticket 4 ---
# TEXT      : Account bloccato: utente mario.rossi fermo (troppi tentativi) Controllo qualità dati contabili storici per archivio. Verifica di routine sulla coerenza dei vecchi movimenti di anni passati. Non blocca nessuna attività corrente e non richiede correzioni urgenti. Si può procedere gradualmente alla validazione dei record passati.
# TEXT_CLEAN: account bloccato utente mario rossi fermo troppi tentativi controllo qualità dati contabili storici per archivio verifica di routine sulla coerenza dei vecchi movimenti di anni passati non blocca nessuna attività corrente e non richiede correzioni urgenti si può procedere gradualmente alla validazione dei record passati

# %% [markdown]
# ## 5. Analisi delle lunghezze dei testi
#
# Analisi la lunghezza dei testi (in parole) prima e dopo la pulizia al fine di capire quanto contesto avranno a disposizione i modelli

# %%
# numero di parole prima e dopo la pulizia
df["len_words_raw"] = df["text"].str.split().str.len()
df["len_words_clean"] = df["text_clean"].str.split().str.len()

summary = df[["len_words_raw", "len_words_clean"]].describe().T
print(summary)

# controllo ticket estremamente corti
print("\nEsempi di ticket molto corti (<= 3 parole pulite):\n")
short_mask = df["len_words_clean"] <= 3
df[short_mask][["id", "text", "text_clean", "len_words_clean"]].head(10)
# Out:
#                  count       mean       std   min    25%   50%   75%   max
# len_words_raw    480.0  46.610417  7.024584  31.0  41.75  46.0  51.0  75.0
# len_words_clean  480.0  47.604167  7.467227  33.0  43.00  47.0  52.0  79.0
#
# Esempi di ticket molto corti (<= 3 parole pulite):
# Empty DataFrame
# Columns: [id, text, text_clean, len_words_clean]
# Index: []

# %% [markdown]
# ## 6. Suddivisione train/test
#
# Utilizzo di `train_test_split` scikit-learn per dividere il dataset in due parti (training set e test set) sul testo grezzo (`text`) e sulle etichette:
#
# - `category` (classificazione della tipologia di ticket)
# - `priority` (bassa / media / alta)
#
# Uso di `stratify` sulla categoria per mantenere una distribuzione simile nel train e nel test.

# %%
 # Controllo che le colonne target esistano
for col in ["category", "priority"]:
    if col not in df.columns:
        raise ValueError(f"La colonna target '{col}' non esiste nel dataset. Controlla il generatore di dataset.")

X = df["text"] 

y_cat = df["category"]
y_pri = df["priority"]

X_train, X_test, y_cat_train, y_cat_test = train_test_split(
    X,
    y_cat,
    test_size=0.2,
    random_state=42,
    stratify=y_cat
)

# riallineo anche le priorità usando gli indici
y_pri_train = df.loc[X_train.index, "priority"]
y_pri_test  = df.loc[X_test.index,  "priority"]

print("Dimensioni train/test:")
print("X_train:", X_train.shape[0])
print("X_test :", X_test.shape[0])
# Out:
# Dimensioni train/test:
# X_train: 384
# X_test : 96

# %% [markdown]
# ## 7. Controllo della distribuzione delle classi
#
# Verifica della distribuzione categorie affinchè sia simile nel dataset completo, nel train e nel test.

# %%
def print_distribution_and_counts(label, series_full, series_train, series_test):
    """Stampa distribuzioni percentuali e conteggi assoluti per full/train/test di una variabile target."""
    
    datasets = {
        "full" : series_full,
        "train": series_train,
        "test" : series_test
    }
    
    print(f"\n=== {label.upper()} ===")

    # Distribuzioni percentuali
    print("\nDistribuzioni percentuali (%):")
    for name, s in datasets.items():
        perc = s.value_counts(normalize=True).mul(100).round(2)
        print(f"\n{name}:")
        print(perc)

    # Conteggi assoluti
    print("\nConteggi assoluti:")
    for name, s in datasets.items():
        print(f"\n{name}:")
        print(s.value_counts())


# Uso della funzione
print_distribution_and_counts("Category", y_cat, y_cat_train, y_cat_test)
print_distribution_and_counts("Priority", y_pri, y_pri_train, y_pri_test)
# Out:
# === CATEGORY ===
#
# Distribuzioni percentuali (%):
#
# full:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# train:
# category
# Tecnico            45.05
# Amministrazione    29.95
# Commerciale        25.00
# Name: proportion, dtype: float64
#
# test:
# category
# Tecnico            44.79
# Amministrazione    30.21
# Commerciale        25.00
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# category
# Tecnico            216
# Amministrazione    144
# Commerciale        120
# Name: count, dtype: int64
#
# train:
# category
# Tecnico            173
# Amministrazione    115
# Commerciale         96
# Name: count, dtype: int64
#
# test:
# category
# Tecnico            43
# Amministrazione    29
# Commerciale        24
# Name: count, dtype: int64
#
# === PRIORITY ===
#
# Distribuzioni percentuali (%):
#
# full:
# priority
# media    39.58
# alta     31.46
# bassa    28.96
# Name: proportion, dtype: float64
#
# train:
# priority
# media    39.32
# alta     33.85
# bassa    26.82
# Name: proportion, dtype: float64
#
# test:
# priority
# media    40.62
# bassa    37.50
# alta     21.88
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# priority
# media    190
# alta     151
# bassa    139
# Name: count, dtype: int64
#
# train:
# priority
# media    151
# alta     130
# bassa    103
# Name: count, dtype: int64
#
# test:
# priority
# media    39
# bassa    36
# alta     21
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Salvataggio del dataset con indicazione train/test
#
# Viene aggiunta una colonna `split` al DataFrame (`train` / `test`) e salvato un CSV aggiornato, che sarà il punto di partenza per EDA e training.

# %%
# inizialmente tutto train
df["split"] = "train"

# assegno 'test' alle righe presenti in X_test
df.loc[X_test.index, "split"] = "test"

print(df["split"].value_counts())

# TODO: adatta il path/output
output_path = DATA_DIR / "splits" / "tickets_preprocessed_split.csv"
df.to_csv(output_path, index=False)
print(f"\nFile salvato in: {output_path}")
# Out:
# split
# train    384
# test      96
# Name: count, dtype: int64
#
# File salvato in: C:\project-work\data\splits\tickets_preprocessed_split.csv
