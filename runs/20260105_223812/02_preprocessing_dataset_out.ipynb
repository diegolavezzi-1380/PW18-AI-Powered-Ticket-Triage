# %% [markdown]
# # Preprocessing NLP per ticket di supporto
#
# In questo notebook vengono preparati i dati testuali dei ticket per l'addestramento dei modelli di classificazione:
# - costruzione del campo testuale (oggetto + descrizione)
# - pulizia testuale semplice e riproducibile
# - analisi di base delle lunghezze
# - suddivisione train/test senza leakage

# %%
import pandas as pd
import re

from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"

from sklearn.model_selection import train_test_split

pd.set_option("display.max_colwidth", 200)

df = pd.read_csv(DATA_DIR / "raw" / "tickets_realistic.csv")

print("Shape iniziale:", df.shape)
df.head()
# Out:
# Shape iniziale: (4800, 7)
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                   title  \
# 0                 Errore calcolo IVA: importo errato su fattura estera (non validabile)
# 1  Funzione rotta: tasto upload PDF non cliccabile per sincronizzazione - disponibilità
# 2          Mancata notifica: email approvazione persa (processo fermo) - errore critico
# 3                                            Task: aggiornamento anagrafica pianificato
# 4                                 Archivio: documentazione storica 1992 con performance
#
#                                                                                                                                                                                                       body  \
# 0  Data entry: modifica scheda informativa cliente Giulietti s.rl... update campi email bcuriel@luna.it e referente admin_01. Modifica puramente formale per completezza anagrafica. Attività amminisrt...
# 1  Procedura di backup storico: export fatture anno 1983 per archivio sicurezza. Generazione file statico in formato XML da conservare serevr-side. Operazione a bassa priorità da accodare ai job nott...
# 2  ASAP completare la registrazione del pagamento per l'ordine ORD-66534 del cliente Casellati, Tropea e Cattaneo s.r.l.. Il sistema mostra erroer 503 durante l'inserimento dell'importo 5582.6 in mag...
# 3  Errore di stampa isolato: impossibile stampare la fatt. 9793/24. Il sistema genera il PDF correttamente a video, ma l'invio alla stampante fallisce. Altre fatture vengono tsampate regolarmente. Il...
# 4  Proposta di manutenzione ordinaria: pulizia account inattiiv da lungo periodo. Lista di 6 utenti che non accedono da mesi. Attività di igiene del database da schedulare come task di routine. Nessu...
#
#           category priority  title_length  body_length
# 0  Amministrazione    media            69          260
# 1  Amministrazione    bassa            84          266
# 2  Amministrazione     alta            76          416
# 3  Amministrazione    media            42          283
# 4  Amministrazione    bassa            53          256

# %% [markdown]
# ## 2. Costruzione del campo testuale unico
#
# Vengono uniti oggetto e descrizione del ticket in un singolo campo `text`, che sarà utilizzato come input testuale per tutti i modelli.

# %%
TITLE_COL = "title"      
BODY_COL  = "body"       

# Controllo che le colonne esistano
print("Colonne presenti:", df.columns.tolist())
if TITLE_COL not in df.columns or BODY_COL not in df.columns:
    raise ValueError(f"Le colonne {TITLE_COL} e/o {BODY_COL} non esistono nel dataset. Adattale prima di proseguire.")

# Costruzione del campo testuale
df["text"] = (
    df[TITLE_COL].fillna("").astype(str) + " " + df[BODY_COL].fillna("").astype(str)
).str.strip()

# Rimuovo righe con testo completamente vuoto
before = df.shape[0]
df = df[df["text"].str.len() > 0].copy()
after = df.shape[0]

print(f"Righe totali dopo rimozione testi vuoti: {after} (rimosse {before - after})")
df[["id", TITLE_COL, BODY_COL, "text"]].head()
# Out:
# Colonne presenti: ['id', 'title', 'body', 'category', 'priority', 'title_length', 'body_length']
# Righe totali dopo rimozione testi vuoti: 4800 (rimosse 0)
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                   title  \
# 0                 Errore calcolo IVA: importo errato su fattura estera (non validabile)
# 1  Funzione rotta: tasto upload PDF non cliccabile per sincronizzazione - disponibilità
# 2          Mancata notifica: email approvazione persa (processo fermo) - errore critico
# 3                                            Task: aggiornamento anagrafica pianificato
# 4                                 Archivio: documentazione storica 1992 con performance
#
#                                                                                                                                                                                                       body  \
# 0  Data entry: modifica scheda informativa cliente Giulietti s.rl... update campi email bcuriel@luna.it e referente admin_01. Modifica puramente formale per completezza anagrafica. Attività amminisrt...
# 1  Procedura di backup storico: export fatture anno 1983 per archivio sicurezza. Generazione file statico in formato XML da conservare serevr-side. Operazione a bassa priorità da accodare ai job nott...
# 2  ASAP completare la registrazione del pagamento per l'ordine ORD-66534 del cliente Casellati, Tropea e Cattaneo s.r.l.. Il sistema mostra erroer 503 durante l'inserimento dell'importo 5582.6 in mag...
# 3  Errore di stampa isolato: impossibile stampare la fatt. 9793/24. Il sistema genera il PDF correttamente a video, ma l'invio alla stampante fallisce. Altre fatture vengono tsampate regolarmente. Il...
# 4  Proposta di manutenzione ordinaria: pulizia account inattiiv da lungo periodo. Lista di 6 utenti che non accedono da mesi. Attività di igiene del database da schedulare come task di routine. Nessu...
#
#                                                                                                                                                                                                       text
# 0  Errore calcolo IVA: importo errato su fattura estera (non validabile) Data entry: modifica scheda informativa cliente Giulietti s.rl... update campi email bcuriel@luna.it e referente admin_01. Mod...
# 1  Funzione rotta: tasto upload PDF non cliccabile per sincronizzazione - disponibilità Procedura di backup storico: export fatture anno 1983 per archivio sicurezza. Generazione file statico in forma...
# 2  Mancata notifica: email approvazione persa (processo fermo) - errore critico ASAP completare la registrazione del pagamento per l'ordine ORD-66534 del cliente Casellati, Tropea e Cattaneo s.r.l.. ...
# 3  Task: aggiornamento anagrafica pianificato Errore di stampa isolato: impossibile stampare la fatt. 9793/24. Il sistema genera il PDF correttamente a video, ma l'invio alla stampante fallisce. Altr...
# 4  Archivio: documentazione storica 1992 con performance Proposta di manutenzione ordinaria: pulizia account inattiiv da lungo periodo. Lista di 6 utenti che non accedono da mesi. Attività di igiene ...

# %% [markdown]
# ## 3. Pulizia testuale semplice
#
# Viene definita una funzione `clean_text` che applica:
#
# - conversione in minuscolo
# - rimozione dei simboli non utili
# - normalizzazione degli spazi

# %%
def clean_text(text: str) -> str:
    if not isinstance(text, str):
        text = "" if text is None else str(text)
        
    # minuscole 
    text = text.lower()
    
    # rimuovi solo simboli non utili
    text = re.sub(r"[^\w\sàèéìòù]", " ", text)
    
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Test veloce della funzione su un esempio
example = "URGENTE: Fattura 12345 non pagata!!!"
print("Originale:", example)
print("Pulito   :", clean_text(example))
# Out:
# Originale: URGENTE: Fattura 12345 non pagata!!!
# Pulito   : urgente fattura 12345 non pagata

# %% [markdown]
# ## 4. Applicazione della pulizia e controlli di base
#
# Applicazione di `clean_text` al campo `text` per ottenere `text_clean` e verifica dei primi 5 record prima/dopo

# %%
df["text_clean"] = df["text"].apply(clean_text)

print("Esempi di testo prima/dopo:\n")
for i in range(5):
    print(f"--- Ticket {i} ---")
    print("TEXT      :", df.iloc[i]["text"])
    print("TEXT_CLEAN:", df.iloc[i]["text_clean"])
    print()
# Out:
# Esempi di testo prima/dopo:
#
# --- Ticket 0 ---
# TEXT      : Errore calcolo IVA: importo errato su fattura estera (non validabile) Data entry: modifica scheda informativa cliente Giulietti s.rl... update campi email bcuriel@luna.it e referente admin_01. Modifica puramente formale per completezza anagrafica. Attività amminisrtativa standard di basso ilvello, gestibile in background.  help!
# TEXT_CLEAN: errore calcolo iva importo errato su fattura estera non validabile data entry modifica scheda informativa cliente giulietti s rl update campi email bcuriel luna it e referente admin_01 modifica puramente formale per completezza anagrafica attività amminisrtativa standard di basso ilvello gestibile in background help
#
# --- Ticket 1 ---
# TEXT      : Funzione rotta: tasto upload PDF non cliccabile per sincronizzazione - disponibilità Procedura di backup storico: export fatture anno 1983 per archivio sicurezza. Generazione file statico in formato XML da conservare serevr-side. Operazione a bassa priorità da accodare ai job notturni o weekend. Serve solo per copmliance e non per attività correnti.
# TEXT_CLEAN: funzione rotta tasto upload pdf non cliccabile per sincronizzazione disponibilità procedura di backup storico export fatture anno 1983 per archivio sicurezza generazione file statico in formato xml da conservare serevr side operazione a bassa priorità da accodare ai job notturni o weekend serve solo per copmliance e non per attività correnti
#
# --- Ticket 2 ---
# TEXT      : Mancata notifica: email approvazione persa (processo fermo) - errore critico ASAP completare la registrazione del pagamento per l'ordine ORD-66534 del cliente Casellati, Tropea e Cattaneo s.r.l.. Il sistema mostra erroer 503 durante l'inserimento dell'importo 5582.6 in magazzino. Il bonifico risulta effettuato ma il gestionale non salva i dati. Blocco crtiico che impedisce conferma ordine e spedizione merce. iRchiesto supoprto tecnico immediato. per sconto per sincronizzazione con scontof
# TEXT_CLEAN: mancata notifica email approvazione persa processo fermo errore critico asap completare la registrazione del pagamento per l ordine ord 66534 del cliente casellati tropea e cattaneo s r l il sistema mostra erroer 503 durante l inserimento dell importo 5582 6 in magazzino il bonifico risulta effettuato ma il gestionale non salva i dati blocco crtiico che impedisce conferma ordine e spedizione merce irchiesto supoprto tecnico immediato per sconto per sincronizzazione con scontof
#
# --- Ticket 3 ---
# TEXT      : Task: aggiornamento anagrafica pianificato Errore di stampa isolato: impossibile stampare la fatt. 9793/24. Il sistema genera il PDF correttamente a video, ma l'invio alla stampante fallisce. Altre fatture vengono tsampate regolarmente. Il cliente Fieramosca, Monti e Nievo Group è in attesa del cartaceo per il irtiro merec.o
# TEXT_CLEAN: task aggiornamento anagrafica pianificato errore di stampa isolato impossibile stampare la fatt 9793 24 il sistema genera il pdf correttamente a video ma l invio alla stampante fallisce altre fatture vengono tsampate regolarmente il cliente fieramosca monti e nievo group è in attesa del cartaceo per il irtiro merec o
#
# --- Ticket 4 ---
# TEXT      : Archivio: documentazione storica 1992 con performance Proposta di manutenzione ordinaria: pulizia account inattiiv da lungo periodo. Lista di 6 utenti che non accedono da mesi. Attività di igiene del database da schedulare come task di routine. Nessun impatto sugli utenti attivi o sul servizio di produzione.i
# TEXT_CLEAN: archivio documentazione storica 1992 con performance proposta di manutenzione ordinaria pulizia account inattiiv da lungo periodo lista di 6 utenti che non accedono da mesi attività di igiene del database da schedulare come task di routine nessun impatto sugli utenti attivi o sul servizio di produzione i

# %% [markdown]
# ## 5. Analisi delle lunghezze dei testi
#
# Analisi la lunghezza dei testi (in parole) prima e dopo la pulizia al fine di capire quanto contesto avranno a disposizione i modelli

# %%
# numero di parole prima e dopo la pulizia
df["len_words_raw"] = df["text"].str.split().str.len()
df["len_words_clean"] = df["text_clean"].str.split().str.len()

summary = df[["len_words_raw", "len_words_clean"]].describe().T
print(summary)

# controllo ticket estremamente corti
print("\nEsempi di ticket molto corti (<= 3 parole pulite):\n")
short_mask = df["len_words_clean"] <= 3
df[short_mask][["id", "text", "text_clean", "len_words_clean"]].head(10)
# Out:
#                   count       mean       std   min   25%   50%   75%   max
# len_words_raw    4800.0  46.755000  7.350509  30.0  41.0  46.0  52.0  73.0
# len_words_clean  4800.0  47.845417  7.751228  30.0  42.0  47.0  53.0  80.0
#
# Esempi di ticket molto corti (<= 3 parole pulite):
# Empty DataFrame
# Columns: [id, text, text_clean, len_words_clean]
# Index: []

# %% [markdown]
# ## 6. Suddivisione train/test
#
# Utilizzo di `train_test_split` scikit-learn per dividere il dataset in due parti (training set e test set) sul testo grezzo (`text`) e sulle etichette:
#
# - `category` (classificazione della tipologia di ticket)
# - `priority` (bassa / media / alta)
#
# Uso di `stratify` sulla combinazione di categoria e priorità per mantenere una distribuzione simile nel train e nel test.

# %%
 # Controllo che le colonne target esistano
for col in ["category", "priority"]:
    if col not in df.columns:
        raise ValueError(f"La colonna target '{col}' non esiste nel dataset. Controlla il generatore di dataset.")

X = df["text"] 

y_cat = df["category"]
y_pri = df["priority"]
strat = df["category"].astype(str) + "||" + df["priority"].astype(str)

X_train, X_test, y_cat_train, y_cat_test = train_test_split(
    X,
    y_cat,
    test_size=0.2,
    random_state=42,
    stratify=strat
)

# riallineo anche le priorità usando gli indici
y_pri_train = df.loc[X_train.index, "priority"]
y_pri_test  = df.loc[X_test.index,  "priority"]

print("Dimensioni train/test:")
print("X_train:", X_train.shape[0])
print("X_test :", X_test.shape[0])
# Out:
# Dimensioni train/test:
# X_train: 3840
# X_test : 960

# %% [markdown]
# ## 7. Controllo della distribuzione delle classi
#
# Verifica della distribuzione categorie affinchè sia simile nel dataset completo, nel train e nel test.

# %%
def print_distribution_and_counts(label, series_full, series_train, series_test):
    """Stampa distribuzioni percentuali e conteggi assoluti per full/train/test di una variabile target."""
    
    datasets = {
        "full" : series_full,
        "train": series_train,
        "test" : series_test
    }
    
    print(f"\n=== {label.upper()} ===")

    # Distribuzioni percentuali
    print("\nDistribuzioni percentuali (%):")
    for name, s in datasets.items():
        perc = s.value_counts(normalize=True).mul(100).round(2)
        print(f"\n{name}:")
        print(perc)

    # Conteggi assoluti
    print("\nConteggi assoluti:")
    for name, s in datasets.items():
        print(f"\n{name}:")
        print(s.value_counts())


# Uso della funzione
print_distribution_and_counts("Category", y_cat, y_cat_train, y_cat_test)
print_distribution_and_counts("Priority", y_pri, y_pri_train, y_pri_test)
# Out:
# === CATEGORY ===
#
# Distribuzioni percentuali (%):
#
# full:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# train:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# test:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# category
# Tecnico            2160
# Amministrazione    1440
# Commerciale        1200
# Name: count, dtype: int64
#
# train:
# category
# Tecnico            1728
# Amministrazione    1152
# Commerciale         960
# Name: count, dtype: int64
#
# test:
# category
# Tecnico            432
# Amministrazione    288
# Commerciale        240
# Name: count, dtype: int64
#
# === PRIORITY ===
#
# Distribuzioni percentuali (%):
#
# full:
# priority
# media    38.08
# alta     32.92
# bassa    29.00
# Name: proportion, dtype: float64
#
# train:
# priority
# media    38.10
# alta     32.92
# bassa    28.98
# Name: proportion, dtype: float64
#
# test:
# priority
# media    38.02
# alta     32.92
# bassa    29.06
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# priority
# media    1828
# alta     1580
# bassa    1392
# Name: count, dtype: int64
#
# train:
# priority
# media    1463
# alta     1264
# bassa    1113
# Name: count, dtype: int64
#
# test:
# priority
# media    365
# alta     316
# bassa    279
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Salvataggio del dataset con indicazione train/test
#
# Viene aggiunta una colonna `split` al DataFrame (`train` / `test`) e salvato un CSV aggiornato, che sarà il punto di partenza per il training.

# %%
# inizialmente tutto train
df["split"] = "train"

# assegno 'test' alle righe presenti in X_test
df.loc[X_test.index, "split"] = "test"

print(df["split"].value_counts())

# TODO: adatta il path/output
output_path = DATA_DIR / "splits" / "tickets_preprocessed_split.csv"
df.to_csv(output_path, index=False)
print(f"\nFile salvato in: {output_path}")
# Out:
# split
# train    3840
# test      960
# Name: count, dtype: int64
#
# File salvato in: C:\project-work\data\splits\tickets_preprocessed_split.csv
