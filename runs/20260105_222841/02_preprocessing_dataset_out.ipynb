# %% [markdown]
# # Preprocessing NLP per ticket di supporto
#
# In questo notebook vengono preparati i dati testuali dei ticket per l'addestramento dei modelli di classificazione:
# - costruzione del campo testuale (oggetto + descrizione)
# - pulizia testuale semplice e riproducibile
# - analisi di base delle lunghezze
# - suddivisione train/test senza leakage

# %%
import pandas as pd
import re

from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"

from sklearn.model_selection import train_test_split

pd.set_option("display.max_colwidth", 200)

df = pd.read_csv(DATA_DIR / "raw" / "tickets_realistic.csv")

print("Shape iniziale:", df.shape)
df.head()
# Out:
# Shape iniziale: (480, 7)
#    id                                                                title  \
# 0   1                                Archivio: documentazione storica 2012
# 1   2      err. validazione: codice fiscale corretto rifiutato dal sistema
# 2   3                                 Batch: consolidamento dati contabili
# 3   4                      Monitoraggio: log modulo utenti (nessun errore)
# 4   5  Log: inserimento anagrafica Smirnoff, Mascheroni e Squarcione Group
#
#                                                                                                                                                                                                       body  \
# 0  Monitroaggio passivo dei log modulo gestione utenti per statistiche utliizzo. Analisi a posteriori dei tracciati per identificare trend di lungo periodo. Non ci sono errori attivi o malfunzionamen...
# 1  tAtività di background: archiviazione documneti storici cliente Verga-Magnani s.r.l. per anno 2011. Si tratta di spostare vecchi file (fatture, contratti) nell'archivio morto per liberare spazio. ...
# 2  Il sys. clienti non risponde alle richieste di accesso da parte degli utenti amministrativi. Abbiamo la produzione ferma: impossibile gestrie le anagrafiche clienti e fornitori. Circa 1 utenti blo...
# 3  Mancata ricezione notifica approvazione ordine ORD-74909. Il responsabile ha approvato, ma l'email non è arrivata all'amministrazione. Senza notifica la fatturazione non parte. checkre code di pos...
# 4  Richiesta estrazione dati statistici su utilizzo licenze Linea Enterprise. Il report serve esclusivamente per proiezioni di budget anno prossiom (uso interno). Nessuna scadenza operativa immediata...
#
#           category priority  title_length  body_length
# 0  Amministrazione    media            37          294
# 1  Amministrazione    bassa            63          331
# 2  Amministrazione     alta            36          367
# 3  Amministrazione    media            47          238
# 4  Amministrazione    bassa            67          303

# %% [markdown]
# ## 2. Costruzione del campo testuale unico
#
# Vengono uniti oggetto e descrizione del ticket in un singolo campo `text`, che sarà utilizzato come input testuale per tutti i modelli.

# %%
TITLE_COL = "title"      
BODY_COL  = "body"       

# Controllo che le colonne esistano
print("Colonne presenti:", df.columns.tolist())
if TITLE_COL not in df.columns or BODY_COL not in df.columns:
    raise ValueError(f"Le colonne {TITLE_COL} e/o {BODY_COL} non esistono nel dataset. Adattale prima di proseguire.")

# Costruzione del campo testuale
df["text"] = (
    df[TITLE_COL].fillna("").astype(str) + " " + df[BODY_COL].fillna("").astype(str)
).str.strip()

# Rimuovo righe con testo completamente vuoto
before = df.shape[0]
df = df[df["text"].str.len() > 0].copy()
after = df.shape[0]

print(f"Righe totali dopo rimozione testi vuoti: {after} (rimosse {before - after})")
df[["id", TITLE_COL, BODY_COL, "text"]].head()
# Out:
# Colonne presenti: ['id', 'title', 'body', 'category', 'priority', 'title_length', 'body_length']
# Righe totali dopo rimozione testi vuoti: 480 (rimosse 0)
#    id                                                                title  \
# 0   1                                Archivio: documentazione storica 2012
# 1   2      err. validazione: codice fiscale corretto rifiutato dal sistema
# 2   3                                 Batch: consolidamento dati contabili
# 3   4                      Monitoraggio: log modulo utenti (nessun errore)
# 4   5  Log: inserimento anagrafica Smirnoff, Mascheroni e Squarcione Group
#
#                                                                                                                                                                                                       body  \
# 0  Monitroaggio passivo dei log modulo gestione utenti per statistiche utliizzo. Analisi a posteriori dei tracciati per identificare trend di lungo periodo. Non ci sono errori attivi o malfunzionamen...
# 1  tAtività di background: archiviazione documneti storici cliente Verga-Magnani s.r.l. per anno 2011. Si tratta di spostare vecchi file (fatture, contratti) nell'archivio morto per liberare spazio. ...
# 2  Il sys. clienti non risponde alle richieste di accesso da parte degli utenti amministrativi. Abbiamo la produzione ferma: impossibile gestrie le anagrafiche clienti e fornitori. Circa 1 utenti blo...
# 3  Mancata ricezione notifica approvazione ordine ORD-74909. Il responsabile ha approvato, ma l'email non è arrivata all'amministrazione. Senza notifica la fatturazione non parte. checkre code di pos...
# 4  Richiesta estrazione dati statistici su utilizzo licenze Linea Enterprise. Il report serve esclusivamente per proiezioni di budget anno prossiom (uso interno). Nessuna scadenza operativa immediata...
#
#                                                                                                                                                                                                       text
# 0  Archivio: documentazione storica 2012 Monitroaggio passivo dei log modulo gestione utenti per statistiche utliizzo. Analisi a posteriori dei tracciati per identificare trend di lungo periodo. Non ...
# 1  err. validazione: codice fiscale corretto rifiutato dal sistema tAtività di background: archiviazione documneti storici cliente Verga-Magnani s.r.l. per anno 2011. Si tratta di spostare vecchi fil...
# 2  Batch: consolidamento dati contabili Il sys. clienti non risponde alle richieste di accesso da parte degli utenti amministrativi. Abbiamo la produzione ferma: impossibile gestrie le anagrafiche cl...
# 3  Monitoraggio: log modulo utenti (nessun errore) Mancata ricezione notifica approvazione ordine ORD-74909. Il responsabile ha approvato, ma l'email non è arrivata all'amministrazione. Senza notific...
# 4  Log: inserimento anagrafica Smirnoff, Mascheroni e Squarcione Group Richiesta estrazione dati statistici su utilizzo licenze Linea Enterprise. Il report serve esclusivamente per proiezioni di budg...

# %% [markdown]
# ## 3. Pulizia testuale semplice
#
# Viene definita una funzione `clean_text` che applica:
#
# - conversione in minuscolo
# - rimozione dei simboli non utili
# - normalizzazione degli spazi

# %%
def clean_text(text: str) -> str:
    if not isinstance(text, str):
        text = "" if text is None else str(text)
        
    # minuscole 
    text = text.lower()
    
    # rimuovi solo simboli non utili
    text = re.sub(r"[^\w\sàèéìòù]", " ", text)
    
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Test veloce della funzione su un esempio
example = "URGENTE: Fattura 12345 non pagata!!!"
print("Originale:", example)
print("Pulito   :", clean_text(example))
# Out:
# Originale: URGENTE: Fattura 12345 non pagata!!!
# Pulito   : urgente fattura 12345 non pagata

# %% [markdown]
# ## 4. Applicazione della pulizia e controlli di base
#
# Applicazione di `clean_text` al campo `text` per ottenere `text_clean` e verifica dei primi 5 record prima/dopo

# %%
df["text_clean"] = df["text"].apply(clean_text)

print("Esempi di testo prima/dopo:\n")
for i in range(5):
    print(f"--- Ticket {i} ---")
    print("TEXT      :", df.iloc[i]["text"])
    print("TEXT_CLEAN:", df.iloc[i]["text_clean"])
    print()
# Out:
# Esempi di testo prima/dopo:
#
# --- Ticket 0 ---
# TEXT      : Archivio: documentazione storica 2012 Monitroaggio passivo dei log modulo gestione utenti per statistiche utliizzo. Analisi a posteriori dei tracciati per identificare trend di lungo periodo. Non ci sono errori attivi o malfunzionamenti. Attività di studio per future ottimizzazioni, senza impatto attuale. - timeout per performance
# TEXT_CLEAN: archivio documentazione storica 2012 monitroaggio passivo dei log modulo gestione utenti per statistiche utliizzo analisi a posteriori dei tracciati per identificare trend di lungo periodo non ci sono errori attivi o malfunzionamenti attività di studio per future ottimizzazioni senza impatto attuale timeout per performance
#
# --- Ticket 1 ---
# TEXT      : err. validazione: codice fiscale corretto rifiutato dal sistema tAtività di background: archiviazione documneti storici cliente Verga-Magnani s.r.l. per anno 2011. Si tratta di spostare vecchi file (fatture, contratti) nell'archivio morto per liberare spazio. Nessuna urgenza operativa: il task può girare nei momenti di inattività del sistema. Operazione di manutenzione ordinaria del database.
# TEXT_CLEAN: err validazione codice fiscale corretto rifiutato dal sistema tatività di background archiviazione documneti storici cliente verga magnani s r l per anno 2011 si tratta di spostare vecchi file fatture contratti nell archivio morto per liberare spazio nessuna urgenza operativa il task può girare nei momenti di inattività del sistema operazione di manutenzione ordinaria del database
#
# --- Ticket 2 ---
# TEXT      : Batch: consolidamento dati contabili Il sys. clienti non risponde alle richieste di accesso da parte degli utenti amministrativi. Abbiamo la produzione ferma: impossibile gestrie le anagrafiche clienti e fornitori. Circa 1 utenti bloccati, nessuno riesce ad accedere alle funzionalità di gestione documenti. Il issue si manifesta in ambiente pre-produzione con timeout continui. per login fallito con bug
# TEXT_CLEAN: batch consolidamento dati contabili il sys clienti non risponde alle richieste di accesso da parte degli utenti amministrativi abbiamo la produzione ferma impossibile gestrie le anagrafiche clienti e fornitori circa 1 utenti bloccati nessuno riesce ad accedere alle funzionalità di gestione documenti il issue si manifesta in ambiente pre produzione con timeout continui per login fallito con bug
#
# --- Ticket 3 ---
# TEXT      : Monitoraggio: log modulo utenti (nessun errore) Mancata ricezione notifica approvazione ordine ORD-74909. Il responsabile ha approvato, ma l'email non è arrivata all'amministrazione. Senza notifica la fatturazione non parte. checkre code di posta in uscita su ambiente test. performance
# TEXT_CLEAN: monitoraggio log modulo utenti nessun errore mancata ricezione notifica approvazione ordine ord 74909 il responsabile ha approvato ma l email non è arrivata all amministrazione senza notifica la fatturazione non parte checkre code di posta in uscita su ambiente test performance
#
# --- Ticket 4 ---
# TEXT      : Log: inserimento anagrafica Smirnoff, Mascheroni e Squarcione Group Richiesta estrazione dati statistici su utilizzo licenze Linea Enterprise. Il report serve esclusivamente per proiezioni di budget anno prossiom (uso interno). Nessuna scadenza operativa immediata. Elaborazione da fare offline quando le risorse lo permtetono. preventivo - negoziazione con login fallito
# TEXT_CLEAN: log inserimento anagrafica smirnoff mascheroni e squarcione group richiesta estrazione dati statistici su utilizzo licenze linea enterprise il report serve esclusivamente per proiezioni di budget anno prossiom uso interno nessuna scadenza operativa immediata elaborazione da fare offline quando le risorse lo permtetono preventivo negoziazione con login fallito

# %% [markdown]
# ## 5. Analisi delle lunghezze dei testi
#
# Analisi la lunghezza dei testi (in parole) prima e dopo la pulizia al fine di capire quanto contesto avranno a disposizione i modelli

# %%
# numero di parole prima e dopo la pulizia
df["len_words_raw"] = df["text"].str.split().str.len()
df["len_words_clean"] = df["text_clean"].str.split().str.len()

summary = df[["len_words_raw", "len_words_clean"]].describe().T
print(summary)

# controllo ticket estremamente corti
print("\nEsempi di ticket molto corti (<= 3 parole pulite):\n")
short_mask = df["len_words_clean"] <= 3
df[short_mask][["id", "text", "text_clean", "len_words_clean"]].head(10)
# Out:
#                  count       mean       std   min   25%   50%   75%   max
# len_words_raw    480.0  46.443750  7.043035  30.0  41.0  46.0  51.0  74.0
# len_words_clean  480.0  47.420833  7.344916  30.0  42.0  47.0  52.0  77.0
#
# Esempi di ticket molto corti (<= 3 parole pulite):
# Empty DataFrame
# Columns: [id, text, text_clean, len_words_clean]
# Index: []

# %% [markdown]
# ## 6. Suddivisione train/test
#
# Utilizzo di `train_test_split` scikit-learn per dividere il dataset in due parti (training set e test set) sul testo grezzo (`text`) e sulle etichette:
#
# - `category` (classificazione della tipologia di ticket)
# - `priority` (bassa / media / alta)
#
# Uso di `stratify` sulla combinazione di categoria e priorità per mantenere una distribuzione simile nel train e nel test.

# %%
 # Controllo che le colonne target esistano
for col in ["category", "priority"]:
    if col not in df.columns:
        raise ValueError(f"La colonna target '{col}' non esiste nel dataset. Controlla il generatore di dataset.")

X = df["text"] 

y_cat = df["category"]
y_pri = df["priority"]
strat = df["category"].astype(str) + "||" + df["priority"].astype(str)

X_train, X_test, y_cat_train, y_cat_test = train_test_split(
    X,
    y_cat,
    test_size=0.2,
    random_state=42,
    stratify=strat
)

# riallineo anche le priorità usando gli indici
y_pri_train = df.loc[X_train.index, "priority"]
y_pri_test  = df.loc[X_test.index,  "priority"]

print("Dimensioni train/test:")
print("X_train:", X_train.shape[0])
print("X_test :", X_test.shape[0])
# Out:
# Dimensioni train/test:
# X_train: 384
# X_test : 96

# %% [markdown]
# ## 7. Controllo della distribuzione delle classi
#
# Verifica della distribuzione categorie affinchè sia simile nel dataset completo, nel train e nel test.

# %%
def print_distribution_and_counts(label, series_full, series_train, series_test):
    """Stampa distribuzioni percentuali e conteggi assoluti per full/train/test di una variabile target."""
    
    datasets = {
        "full" : series_full,
        "train": series_train,
        "test" : series_test
    }
    
    print(f"\n=== {label.upper()} ===")

    # Distribuzioni percentuali
    print("\nDistribuzioni percentuali (%):")
    for name, s in datasets.items():
        perc = s.value_counts(normalize=True).mul(100).round(2)
        print(f"\n{name}:")
        print(perc)

    # Conteggi assoluti
    print("\nConteggi assoluti:")
    for name, s in datasets.items():
        print(f"\n{name}:")
        print(s.value_counts())


# Uso della funzione
print_distribution_and_counts("Category", y_cat, y_cat_train, y_cat_test)
print_distribution_and_counts("Priority", y_pri, y_pri_train, y_pri_test)
# Out:
# === CATEGORY ===
#
# Distribuzioni percentuali (%):
#
# full:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# train:
# category
# Tecnico            44.79
# Amministrazione    30.21
# Commerciale        25.00
# Name: proportion, dtype: float64
#
# test:
# category
# Tecnico            45.83
# Amministrazione    29.17
# Commerciale        25.00
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# category
# Tecnico            216
# Amministrazione    144
# Commerciale        120
# Name: count, dtype: int64
#
# train:
# category
# Tecnico            172
# Amministrazione    116
# Commerciale         96
# Name: count, dtype: int64
#
# test:
# category
# Tecnico            44
# Amministrazione    28
# Commerciale        24
# Name: count, dtype: int64
#
# === PRIORITY ===
#
# Distribuzioni percentuali (%):
#
# full:
# priority
# media    42.08
# bassa    28.96
# alta     28.96
# Name: proportion, dtype: float64
#
# train:
# priority
# media    42.19
# alta     28.91
# bassa    28.91
# Name: proportion, dtype: float64
#
# test:
# priority
# media    41.67
# bassa    29.17
# alta     29.17
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# priority
# media    202
# bassa    139
# alta     139
# Name: count, dtype: int64
#
# train:
# priority
# media    162
# alta     111
# bassa    111
# Name: count, dtype: int64
#
# test:
# priority
# media    40
# bassa    28
# alta     28
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Salvataggio del dataset con indicazione train/test
#
# Viene aggiunta una colonna `split` al DataFrame (`train` / `test`) e salvato un CSV aggiornato, che sarà il punto di partenza per il training.

# %%
# inizialmente tutto train
df["split"] = "train"

# assegno 'test' alle righe presenti in X_test
df.loc[X_test.index, "split"] = "test"

print(df["split"].value_counts())

# TODO: adatta il path/output
output_path = DATA_DIR / "splits" / "tickets_preprocessed_split.csv"
df.to_csv(output_path, index=False)
print(f"\nFile salvato in: {output_path}")
# Out:
# split
# train    384
# test      96
# Name: count, dtype: int64
#
# File salvato in: C:\project-work\data\splits\tickets_preprocessed_split.csv
