# %% [markdown]
# # Preprocessing NLP per ticket di supporto
#
# In questo notebook vengono preparati i dati testuali dei ticket per l'addestramento dei modelli di classificazione:
# - costruzione del campo testuale (oggetto + descrizione)
# - pulizia testuale semplice e riproducibile
# - analisi di base delle lunghezze
# - suddivisione train/test senza leakage

# %%
import pandas as pd
import re

from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"

from sklearn.model_selection import train_test_split

pd.set_option("display.max_colwidth", 200)

df = pd.read_csv(DATA_DIR / "raw" / "tickets_realistic.csv")

print("Shape iniziale:", df.shape)
df.head()
# Out:
# Shape iniziale: (480, 7)
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                                        title  \
# 0   Discrepanza contabile: bonifico 1110.95 non visibile (chiusura bloccata) - condizioni commerciali condizioni commerciali
# 1                                                                  Info: statistiche licenze Linea Accessori con performance
# 2  Export fallito: report mensile si blocca a metà (serve urgentissimo) - login fallito - login fallito per sincronizzazione
# 3                           Anomalia visiva: duplicazione righe estratto conto (confusione) con listino con sincronizzazione
# 4                                                                                      Archivio: documentazione storica 1981
#
#                                                                                                                                                                                                       body  \
# 0  L'utente giulia.verdi segnala lentezza esasperante nel modulo fatturazione. Il salvataggio di ogni fattura impiega 30-40 secondi. Non è un blocco totale, ma dimezza la produttività dell'ufficio. N...
# 1  Richiesta estrazione dati statistiic su utilizzo licenze Linea Accessori. Il report serve esclusivamente per proiezioni di budget anno prossimo (uso interno). Nessuna scadenza operativa immediata....
# 2  error di stampa isolato: impossiible stampare la fattura 7247/24. Il sistema genera il PDF correttamente a video, ma l'invio alla stampante fallisce. Altre fatture vengono stampate regolarmente. I...
# 3  bug di stampa isolato: impossibile stampare la fattura 6293/24. Il sistema genera il PDF correttamente a video, ma l'invio alla stampante fallisce. Altre fatture vengono stampate regolarmente. Il ...
# 4  Mancata ricezione notifica approvazione ordine ORD-10742. Il responsabile ha approvato, ma l'email non è arrivata all'amministrazione. Senza ontifica la fatturazione non parte. Verifciare code di ...
#
#           category priority  title_length  body_length
# 0  Amministrazione    media           120          260
# 1  Amministrazione    bassa            57          258
# 2  Amministrazione     alta           121          266
# 3  Amministrazione    media            96          339
# 4  Amministrazione    bassa            37          229

# %% [markdown]
# ## 2. Costruzione del campo testuale unico
#
# Vengono uniti oggetto e descrizione del ticket in un singolo campo `text`, che sarà utilizzato come input testuale per tutti i modelli.

# %%
TITLE_COL = "title"      
BODY_COL  = "body"       

# Controllo che le colonne esistano
print("Colonne presenti:", df.columns.tolist())
if TITLE_COL not in df.columns or BODY_COL not in df.columns:
    raise ValueError(f"Le colonne {TITLE_COL} e/o {BODY_COL} non esistono nel dataset. Adattale prima di proseguire.")

# Costruzione del campo testuale
df["text"] = (
    df[TITLE_COL].fillna("").astype(str) + " " + df[BODY_COL].fillna("").astype(str)
).str.strip()

# Rimuovo righe con testo completamente vuoto
before = df.shape[0]
df = df[df["text"].str.len() > 0].copy()
after = df.shape[0]

print(f"Righe totali dopo rimozione testi vuoti: {after} (rimosse {before - after})")
df[["id", TITLE_COL, BODY_COL, "text"]].head()
# Out:
# Colonne presenti: ['id', 'title', 'body', 'category', 'priority', 'title_length', 'body_length']
# Righe totali dopo rimozione testi vuoti: 480 (rimosse 0)
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                                        title  \
# 0   Discrepanza contabile: bonifico 1110.95 non visibile (chiusura bloccata) - condizioni commerciali condizioni commerciali
# 1                                                                  Info: statistiche licenze Linea Accessori con performance
# 2  Export fallito: report mensile si blocca a metà (serve urgentissimo) - login fallito - login fallito per sincronizzazione
# 3                           Anomalia visiva: duplicazione righe estratto conto (confusione) con listino con sincronizzazione
# 4                                                                                      Archivio: documentazione storica 1981
#
#                                                                                                                                                                                                       body  \
# 0  L'utente giulia.verdi segnala lentezza esasperante nel modulo fatturazione. Il salvataggio di ogni fattura impiega 30-40 secondi. Non è un blocco totale, ma dimezza la produttività dell'ufficio. N...
# 1  Richiesta estrazione dati statistiic su utilizzo licenze Linea Accessori. Il report serve esclusivamente per proiezioni di budget anno prossimo (uso interno). Nessuna scadenza operativa immediata....
# 2  error di stampa isolato: impossiible stampare la fattura 7247/24. Il sistema genera il PDF correttamente a video, ma l'invio alla stampante fallisce. Altre fatture vengono stampate regolarmente. I...
# 3  bug di stampa isolato: impossibile stampare la fattura 6293/24. Il sistema genera il PDF correttamente a video, ma l'invio alla stampante fallisce. Altre fatture vengono stampate regolarmente. Il ...
# 4  Mancata ricezione notifica approvazione ordine ORD-10742. Il responsabile ha approvato, ma l'email non è arrivata all'amministrazione. Senza ontifica la fatturazione non parte. Verifciare code di ...
#
#                                                                                                                                                                                                       text
# 0  Discrepanza contabile: bonifico 1110.95 non visibile (chiusura bloccata) - condizioni commerciali condizioni commerciali L'utente giulia.verdi segnala lentezza esasperante nel modulo fatturazione....
# 1  Info: statistiche licenze Linea Accessori con performance Richiesta estrazione dati statistiic su utilizzo licenze Linea Accessori. Il report serve esclusivamente per proiezioni di budget anno pro...
# 2  Export fallito: report mensile si blocca a metà (serve urgentissimo) - login fallito - login fallito per sincronizzazione error di stampa isolato: impossiible stampare la fattura 7247/24. Il siste...
# 3  Anomalia visiva: duplicazione righe estratto conto (confusione) con listino con sincronizzazione bug di stampa isolato: impossibile stampare la fattura 6293/24. Il sistema genera il PDF correttame...
# 4  Archivio: documentazione storica 1981 Mancata ricezione notifica approvazione ordine ORD-10742. Il responsabile ha approvato, ma l'email non è arrivata all'amministrazione. Senza ontifica la fattu...

# %% [markdown]
# ## 3. Pulizia testuale semplice
#
# Viene definita una funzione `clean_text` che applica:
#
# - conversione in minuscolo
# - rimozione dei simboli non utili
# - normalizzazione degli spazi

# %%
def clean_text(text: str) -> str:
    if not isinstance(text, str):
        text = "" if text is None else str(text)
        
    # minuscole (e togli lowercase=False dal TFIDF)
    text = text.lower()
    
    # rimuovi solo simboli non utili
    text = re.sub(r"[^\w\sàèéìòù]", " ", text)
    
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Test veloce della funzione su un esempio
example = "URGENTE: Fattura 12345 non pagata!!!"
print("Originale:", example)
print("Pulito   :", clean_text(example))
# Out:
# Originale: URGENTE: Fattura 12345 non pagata!!!
# Pulito   : urgente fattura 12345 non pagata

# %% [markdown]
# ## 4. Applicazione della pulizia e controlli di base
#
# Applicazione di `clean_text` al campo `text` per ottenere `text_clean` e verifica dei primi 5 record prima/dopo

# %%
df["text_clean"] = df["text"].apply(clean_text)

print("Esempi di testo prima/dopo:\n")
for i in range(5):
    print(f"--- Ticket {i} ---")
    print("TEXT      :", df.iloc[i]["text"])
    print("TEXT_CLEAN:", df.iloc[i]["text_clean"])
    print()
# Out:
# Esempi di testo prima/dopo:
#
# --- Ticket 0 ---
# TEXT      : Discrepanza contabile: bonifico 1110.95 non visibile (chiusura bloccata) - condizioni commerciali condizioni commerciali L'utente giulia.verdi segnala lentezza esasperante nel modulo fatturazione. Il salvataggio di ogni fattura impiega 30-40 secondi. Non è un blocco totale, ma dimezza la produttività dell'ufficio. Necessaria verfiica performance database o rete su ambiente test.
# TEXT_CLEAN: discrepanza contabile bonifico 1110 95 non visibile chiusura bloccata condizioni commerciali condizioni commerciali l utente giulia verdi segnala lentezza esasperante nel modulo fatturazione il salvataggio di ogni fattura impiega 30 40 secondi non è un blocco totale ma dimezza la produttività dell ufficio necessaria verfiica performance database o rete su ambiente test
#
# --- Ticket 1 ---
# TEXT      : Info: statistiche licenze Linea Accessori con performance Richiesta estrazione dati statistiic su utilizzo licenze Linea Accessori. Il report serve esclusivamente per proiezioni di budget anno prossimo (uso interno). Nessuna scadenza operativa immediata. Elaborazione da fare offline quando le risorse lo permettono.
# TEXT_CLEAN: info statistiche licenze linea accessori con performance richiesta estrazione dati statistiic su utilizzo licenze linea accessori il report serve esclusivamente per proiezioni di budget anno prossimo uso interno nessuna scadenza operativa immediata elaborazione da fare offline quando le risorse lo permettono
#
# --- Ticket 2 ---
# TEXT      : Export fallito: report mensile si blocca a metà (serve urgentissimo) - login fallito - login fallito per sincronizzazione error di stampa isolato: impossiible stampare la fattura 7247/24. Il sistema genera il PDF correttamente a video, ma l'invio alla stampante fallisce. Altre fatture vengono stampate regolarmente. Il cliente Mancini s.r.l. è in attesa del cartaceo per il ritiro merce.
# TEXT_CLEAN: export fallito report mensile si blocca a metà serve urgentissimo login fallito login fallito per sincronizzazione error di stampa isolato impossiible stampare la fattura 7247 24 il sistema genera il pdf correttamente a video ma l invio alla stampante fallisce altre fatture vengono stampate regolarmente il cliente mancini s r l è in attesa del cartaceo per il ritiro merce
#
# --- Ticket 3 ---
# TEXT      : Anomalia visiva: duplicazione righe estratto conto (confusione) con listino con sincronizzazione bug di stampa isolato: impossibile stampare la fattura 6293/24. Il sistema genera il PDF correttamente a video, ma l'invio alla stampante fallisce. Altre fatture vengono stampate regolarmente. Il cliente Odescalchi, Druso e Palazzo SPA è in attesa del cartaceo per il ritiro merce., problema su assistenza - performance - sconto preventivo
# TEXT_CLEAN: anomalia visiva duplicazione righe estratto conto confusione con listino con sincronizzazione bug di stampa isolato impossibile stampare la fattura 6293 24 il sistema genera il pdf correttamente a video ma l invio alla stampante fallisce altre fatture vengono stampate regolarmente il cliente odescalchi druso e palazzo spa è in attesa del cartaceo per il ritiro merce problema su assistenza performance sconto preventivo
#
# --- Ticket 4 ---
# TEXT      : Archivio: documentazione storica 1981 Mancata ricezione notifica approvazione ordine ORD-10742. Il responsabile ha approvato, ma l'email non è arrivata all'amministrazione. Senza ontifica la fatturazione non parte. Verifciare code di posta in uscita su ambiente demo.
# TEXT_CLEAN: archivio documentazione storica 1981 mancata ricezione notifica approvazione ordine ord 10742 il responsabile ha approvato ma l email non è arrivata all amministrazione senza ontifica la fatturazione non parte verifciare code di posta in uscita su ambiente demo

# %% [markdown]
# ## 5. Analisi delle lunghezze dei testi
#
# Analisi la lunghezza dei testi (in parole) prima e dopo la pulizia al fine di capire quanto contesto avranno a disposizione i modelli

# %%
# numero di parole prima e dopo la pulizia
df["len_words_raw"] = df["text"].str.split().str.len()
df["len_words_clean"] = df["text_clean"].str.split().str.len()

summary = df[["len_words_raw", "len_words_clean"]].describe().T
print(summary)

# controllo ticket estremamente corti
print("\nEsempi di ticket molto corti (<= 3 parole pulite):\n")
short_mask = df["len_words_clean"] <= 3
df[short_mask][["id", "text", "text_clean", "len_words_clean"]].head(10)
# Out:
#                  count       mean       std   min   25%   50%   75%   max
# len_words_raw    480.0  47.108333  7.194345  32.0  42.0  47.0  52.0  68.0
# len_words_clean  480.0  48.195833  7.645812  33.0  42.0  48.0  53.0  74.0
#
# Esempi di ticket molto corti (<= 3 parole pulite):
# Empty DataFrame
# Columns: [id, text, text_clean, len_words_clean]
# Index: []

# %% [markdown]
# ## 6. Suddivisione train/test
#
# Utilizzo di `train_test_split` scikit-learn per dividere il dataset in due parti (training set e test set) sul testo grezzo (`text`) e sulle etichette:
#
# - `category` (classificazione della tipologia di ticket)
# - `priority` (bassa / media / alta)
#
# Uso di `stratify` sulla categoria per mantenere una distribuzione simile nel train e nel test.

# %%
 # Controllo che le colonne target esistano
for col in ["category", "priority"]:
    if col not in df.columns:
        raise ValueError(f"La colonna target '{col}' non esiste nel dataset. Controlla il generatore di dataset.")

X = df["text"] 

y_cat = df["category"]
y_pri = df["priority"]

X_train, X_test, y_cat_train, y_cat_test = train_test_split(
    X,
    y_cat,
    test_size=0.2,
    random_state=42,
    stratify=y_cat
)

# riallineo anche le priorità usando gli indici
y_pri_train = df.loc[X_train.index, "priority"]
y_pri_test  = df.loc[X_test.index,  "priority"]

print("Dimensioni train/test:")
print("X_train:", X_train.shape[0])
print("X_test :", X_test.shape[0])
# Out:
# Dimensioni train/test:
# X_train: 384
# X_test : 96

# %% [markdown]
# ## 7. Controllo della distribuzione delle classi
#
# Verifica della distribuzione categorie affinchè sia simile nel dataset completo, nel train e nel test.

# %%
def print_distribution_and_counts(label, series_full, series_train, series_test):
    """Stampa distribuzioni percentuali e conteggi assoluti per full/train/test di una variabile target."""
    
    datasets = {
        "full" : series_full,
        "train": series_train,
        "test" : series_test
    }
    
    print(f"\n=== {label.upper()} ===")

    # Distribuzioni percentuali
    print("\nDistribuzioni percentuali (%):")
    for name, s in datasets.items():
        perc = s.value_counts(normalize=True).mul(100).round(2)
        print(f"\n{name}:")
        print(perc)

    # Conteggi assoluti
    print("\nConteggi assoluti:")
    for name, s in datasets.items():
        print(f"\n{name}:")
        print(s.value_counts())


# Uso della funzione
print_distribution_and_counts("Category", y_cat, y_cat_train, y_cat_test)
print_distribution_and_counts("Priority", y_pri, y_pri_train, y_pri_test)
# Out:
# === CATEGORY ===
#
# Distribuzioni percentuali (%):
#
# full:
# category
# Tecnico            45.0
# Amministrazione    30.0
# Commerciale        25.0
# Name: proportion, dtype: float64
#
# train:
# category
# Tecnico            45.05
# Amministrazione    29.95
# Commerciale        25.00
# Name: proportion, dtype: float64
#
# test:
# category
# Tecnico            44.79
# Amministrazione    30.21
# Commerciale        25.00
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# category
# Tecnico            216
# Amministrazione    144
# Commerciale        120
# Name: count, dtype: int64
#
# train:
# category
# Tecnico            173
# Amministrazione    115
# Commerciale         96
# Name: count, dtype: int64
#
# test:
# category
# Tecnico            43
# Amministrazione    29
# Commerciale        24
# Name: count, dtype: int64
#
# === PRIORITY ===
#
# Distribuzioni percentuali (%):
#
# full:
# priority
# media    39.58
# alta     31.46
# bassa    28.96
# Name: proportion, dtype: float64
#
# train:
# priority
# media    39.58
# alta     32.55
# bassa    27.86
# Name: proportion, dtype: float64
#
# test:
# priority
# media    39.58
# bassa    33.33
# alta     27.08
# Name: proportion, dtype: float64
#
# Conteggi assoluti:
#
# full:
# priority
# media    190
# alta     151
# bassa    139
# Name: count, dtype: int64
#
# train:
# priority
# media    152
# alta     125
# bassa    107
# Name: count, dtype: int64
#
# test:
# priority
# media    38
# bassa    32
# alta     26
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Salvataggio del dataset con indicazione train/test
#
# Viene aggiunta una colonna `split` al DataFrame (`train` / `test`) e salvato un CSV aggiornato, che sarà il punto di partenza per EDA e training.

# %%
# inizialmente tutto train
df["split"] = "train"

# assegno 'test' alle righe presenti in X_test
df.loc[X_test.index, "split"] = "test"

print(df["split"].value_counts())

# TODO: adatta il path/output
output_path = DATA_DIR / "splits" / "tickets_preprocessed_split.csv"
df.to_csv(output_path, index=False)
print(f"\nFile salvato in: {output_path}")
# Out:
# split
# train    384
# test      96
# Name: count, dtype: int64
#
# File salvato in: C:\project-work\data\splits\tickets_preprocessed_split.csv
